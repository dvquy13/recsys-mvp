# %% [markdown]
# # LLM Playground: Tagging items

# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio
import concurrent.futures
import os
import sys
import time
from typing import List

import pandas as pd
from datasets import load_dataset
from dotenv import load_dotenv
from loguru import logger
from openai import OpenAI
from pydantic import BaseModel

load_dotenv()

sys.path.insert(0, "..")

from llm.tagger import PROMPT as ITEM_TAGGING_PROMPT
from llm.tagger import SYSTEM_PROMPT
from llm.utils import load_extracted

# %% [markdown]
# # Controller

# %%
class Args(BaseModel):
    testing: bool = False
    run_name: str = "040-llm-tag-items"
    notebook_persist_dp: str = None
    random_seed: int = 41

    user_col: str = "user_id"
    item_col: str = "parent_asin"
    rating_col: str = "rating"
    timestamp_col: str = "timestamp"

    selected_cols: List[str] = ["title", "categories"]

    skip_processed: bool = False
    # processed_fp: str = "/Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/run__040-llm-tag-items__batch__1731068753.jsonl"
    processed_fp: str = None

    def init(self):
        self.notebook_persist_dp = os.path.abspath(f"data/{self.run_name}")
        os.makedirs(self.notebook_persist_dp, exist_ok=True)

        return self


args = Args().init()

print(args.model_dump_json(indent=2))
# Out:
# {
#   "testing": false,
#   "run_name": "040-llm-tag-items",
#   "notebook_persist_dp": "/home/dvquys/frostmourne/tmp/recsys-mvp/notebooks/data/040-llm-tag-items",
#   "random_seed": 41,
#   "user_col": "user_id",
#   "item_col": "parent_asin",
#   "rating_col": "rating",
#   "timestamp_col": "timestamp",
#   "selected_cols": [
#     "title",
#     "categories"
#   ],
#   "skip_processed": false,
#   "processed_fp": null
# }

# %% [markdown]
# # Load data

# %%
metadata_raw = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Video_Games", trust_remote_code=True
)
metadata_df = metadata_raw["full"].to_pandas()
metadata_df
# Out:
#                     main_category  \
# 0                     Video Games
# 1                     Video Games
# 2                     Video Games
# 3                     Video Games
# 4                     Video Games
# ...                           ...
# 137264                       None
# 137265                Video Games
# 137266  Cell Phones & Accessories
# 137267                       None
# 137268                       None
#
#                                                     title  average_rating  \
# 0                          Dash 8-300 Professional Add-On             5.0
# 1                       Phantasmagoria: A Puzzle of Flesh             4.1
# 2        NBA 2K17 - Early Tip Off Edition - PlayStation 4             4.3
# 3       Nintendo Selects: The Legend of Zelda Ocarina ...             4.9
# 4        Thrustmaster Elite Fitness Pack for Nintendo Wii             3.0
# ...                                                   ...             ...
# 137264  Story of Seasons: Pioneers Of Olive Town (Nint...             4.5
# 137265           MotoGP 18 (PC DVD) UK IMPORT REGION FREE             4.0
# 137266  Century Accessory Soft Silicone Protective Ski...             2.9
# 137267  Hasbro Interactive Mr. Potato Head Activity Pa...             3.9
# 137268                                  Worms: Armageddon             4.3
#
#         rating_number                                           features  \
# 0                   1  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                  18                                       [Windows 95]
# 2                 223  [The #1 rated NBA video game simulation series...
# 3                  22  [Authentic Nintendo Selects: The Legend of Zel...
# 4                   3  [Includes (9) Total Accessories, Pedometer, Wi...
# ...               ...                                                ...
# 137264            397  [A wild world of discovery - tame the wilderne...
# 137265              1  [Brand new game engine - MotoGP18 has been reb...
# 137266             19  [Easy access to all buttons, controls and port...
# 137267              5                                                 []
# 137268             13                                                 []
#
#                                               description  price  \
# 0       [The Dash 8-300 Professional Add-On lets you p...   None
# 1                                                      []   None
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 3                                                      []  37.42
# 4       [The Thrustmaster Motion Plus Elite Fitness Pa...   None
# ...                                                   ...    ...
# 137264  [Product Description, Inspired by Tales of you...  31.04
# 137265  [Become the champion of the 2018 MotoGP Season...   None
# 137266  [This soft case cover will add a splash of col...   None
# 137267  [Amazon.com, Everyone's favorite master-of-dis...   None
# 137268  [Product Description, Do you ever wonder what ...   None
#
#                                                    images  \
# 0       {'hi_res': [None], 'large': ['https://m.media-...
# 1       {'hi_res': ['https://m.media-amazon.com/images...
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 3       {'hi_res': ['https://m.media-amazon.com/images...
# 4       {'hi_res': [None, None, None, None, None, None...
# ...                                                   ...
# 137264  {'hi_res': ['https://m.media-amazon.com/images...
# 137265  {'hi_res': ['https://m.media-amazon.com/images...
# 137266  {'hi_res': ['https://m.media-amazon.com/images...
# 137267  {'hi_res': [None, 'https://m.media-amazon.com/...
# 137268  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos              store  \
# 0                 {'title': [], 'url': [], 'user_id': []}           Aerosoft
# 1                 {'title': [], 'url': [], 'user_id': []}             Sierra
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...                 2K
# 3                 {'title': [], 'url': [], 'user_id': []}     Amazon Renewed
# 4                 {'title': [], 'url': [], 'user_id': []}       THRUSTMASTER
# ...                                                   ...                ...
# 137264            {'title': [], 'url': [], 'user_id': []}   Marvelous Europe
# 137265            {'title': [], 'url': [], 'user_id': []}          Milestone
# 137266            {'title': [], 'url': [], 'user_id': []}  Century Accessory
# 137267            {'title': [], 'url': [], 'user_id': []}             Hasbro
# 137268            {'title': [], 'url': [], 'user_id': []}             Hasbro
#
#                                                categories  \
# 0                                [Video Games, PC, Games]
# 1                                [Video Games, PC, Games]
# 2                     [Video Games, PlayStation 4, Games]
# 3       [Video Games, Legacy Systems, Nintendo Systems...
# 4       [Video Games, Legacy Systems, Nintendo Systems...
# ...                                                   ...
# 137264              [Video Games, Nintendo Switch, Games]
# 137265             [Video Games, Game Genre of the Month]
# 137266  [Video Games, Legacy Systems, Xbox Systems, Xb...
# 137267                           [Video Games, PC, Games]
# 137268  [Video Games, Legacy Systems, Sega Systems, Se...
#
#                                                   details parent_asin  \
# 0       {"Pricing": "The strikethrough price is the Li...  B000FH0MHO
# 1       {"Best Sellers Rank": {"Video Games": 137612, ...  B00069EVOG
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 3       {"Best Sellers Rank": {"Video Games": 51019, "...  B07SZJZV88
# 4       {"Release date": "November 1, 2009", "Pricing"...  B002WH4ZJG
# ...                                                   ...         ...
# 137264  {"Release date": "March 26, 2021", "Best Selle...  B09XQJS4CZ
# 137265  {"Pricing": "The strikethrough price is the Li...  B07DGPTGNV
# 137266  {"Package Dimensions": "2.76 x 2.76 x 0.2 inch...  B00HUWCQBW
# 137267  {"Release date": "July 24, 1999", "Best Seller...  B00002S9MH
# 137268  {"Release date": "December 3, 1999", "Best Sel...  B00001OX4N
#
#        bought_together subtitle author
# 0                 None     None   None
# 1                 None     None   None
# 2                 None     None   None
# 3                 None     None   None
# 4                 None     None   None
# ...                ...      ...    ...
# 137264            None     None   None
# 137265            None     None   None
# 137266            None     None   None
# 137267            None     None   None
# 137268            None     None   None
#
# [137269 rows x 16 columns]

# %%
metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")
# Out:
# [{'parent_asin': 'B09ZYFYT5J',
#   'title': 'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch',
#   'categories': array(['Video Games', 'PC', 'Accessories', 'Gaming Keyboards'],
#         dtype=object)},
#  {'parent_asin': 'B00GZ6TX7E',
#   'title': 'NEW HOLLAND SKYLINE [Xbox 360]',
#   'categories': array(['Video Games', 'Legacy Systems', 'Xbox Systems', 'Xbox 360',
#          'Interactive Gaming Figures'], dtype=object)},
#  {'parent_asin': 'B09QZ2RZLV',
#   'title': 'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch',
#   'categories': array(['Video Games', 'Nintendo Switch', 'Accessories'], dtype=object)},
#  {'parent_asin': 'B000021Y1B',
#   'title': 'Rampage 2: Universal Tour',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Nintendo 64',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B07MMP45FS',
#   'title': 'Warner Home Video Lego Jurassic World PS4',
#   'categories': array(['Video Games', 'PlayStation 4', 'Games'], dtype=object)},
#  {'parent_asin': 'B00EEH3U2K',
#   'title': 'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B001A33GMU',
#   'title': 'Mysteryville - PC (Jewel case)',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B0BV24K2CD',
#   'title': 'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Wii',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B00UBRKJFI',
#   'title': 'Wolfenstein The Old Blood\u3000[ceroZ]',
#   'categories': array([], dtype=object)},
#  {'parent_asin': 'B003C3V6WI',
#   'title': 'Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]',
#   'categories': array([], dtype=object)}]

# %% [markdown]
# # Call OpenAI to get tags

# %%
sampled_items = metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")

# %%
prompt = ITEM_TAGGING_PROMPT.format(input_list=sampled_items)
prompt
# Out:
# '\nFor each of the following items, generate a set of tags that capture the main features, target audience, platform compatibility, and item type (e.g., accessory, game, hardware).\n\nReturn the output as a list of JSON objects, where each object includes the original item `title`, `parent_asin`, and a list of tags.\n\nFocus on adding tags that help shoppers easily find these items based on genre, brand associations, and product functionality.\n\nIf possible, add new information that is not obvious from the item title.\n\nDo not include the tags that are similar to those in the input categories, for example do not include tags about gaming platforms as output.\n\n<EXAMPLE>\n\nExample item titles with JSON input and output:\n\nInput:  \n[\n    { "parent_asin": "B09ZYFYT5J", "title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch" },\n    { "parent_asin": "B00GZ6TX7E", "title": "NEW HOLLAND SKYLINE [Xbox 360]" },\n    { "parent_asin": "B09QZ2RZLV", "title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch" }\n]\n\nOutput:  \n[\n    {\n        "parent_asin": "B09ZYFYT5J",\n        "item_title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch",\n        "tags": ["Keyboard Accessory", "Cherry MX", "Mechanical Keyboard", "Switch Film", "Gateron", "Repair"]\n    },\n    {\n        "parent_asin": "B00GZ6TX7E",\n        "item_title": "NEW HOLLAND SKYLINE [Xbox 360]",\n        "tags": ["Racing", "NEW HOLLAND", "Skyline", "Retro"]\n    },\n    {\n        "parent_asin": "B09QZ2RZLV",\n        "item_title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch",\n        "tags": ["Headset", "Nintendo Switch", "Switch Lite", "Pikachu", "Pokemon", "Gaming Accessory"]\n    }\n]\n\n</EXAMPLE>\n\nInput:\n[{\'parent_asin\': \'B09ZYFYT5J\', \'title\': \'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch\', \'categories\': array([\'Video Games\', \'PC\', \'Accessories\', \'Gaming Keyboards\'],\n      dtype=object)}, {\'parent_asin\': \'B00GZ6TX7E\', \'title\': \'NEW HOLLAND SKYLINE [Xbox 360]\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Xbox Systems\', \'Xbox 360\',\n       \'Interactive Gaming Figures\'], dtype=object)}, {\'parent_asin\': \'B09QZ2RZLV\', \'title\': \'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch\', \'categories\': array([\'Video Games\', \'Nintendo Switch\', \'Accessories\'], dtype=object)}, {\'parent_asin\': \'B000021Y1B\', \'title\': \'Rampage 2: Universal Tour\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Nintendo 64\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B07MMP45FS\', \'title\': \'Warner Home Video Lego Jurassic World PS4\', \'categories\': array([\'Video Games\', \'PlayStation 4\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B00EEH3U2K\', \'title\': \'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B001A33GMU\', \'title\': \'Mysteryville - PC (Jewel case)\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B0BV24K2CD\', \'title\': \'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Wii\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B00UBRKJFI ...

# %%
client = OpenAI()


# Define the structured output format using Pydantic for a single item
class ItemTag(BaseModel):
    parent_asin: str
    item_title: str
    tags: List[str]


# Define the output format to wrap the list of items within an object
class ItemTaggingOutput(BaseModel):
    items: List[ItemTag]  # Wrap list in an "items" field

# %%
def retrieve_item_tags_from_llm(item_metadata: List[dict]):
    prompt = ITEM_TAGGING_PROMPT.format(input_list=item_metadata)

    completion = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": SYSTEM_PROMPT,
            },
            {"role": "user", "content": prompt},
        ],
        response_format=ItemTaggingOutput,
    )

    tagged_items = completion.choices[0].message.parsed

    return tagged_items.dict()["items"]

# %%
extracted_tags = retrieve_item_tags_from_llm(sampled_items)
with pd.option_context("display.max_colwidth", None):
    display(pd.DataFrame(extracted_tags))
# Out:
#   parent_asin  \
# 0  B09ZYFYT5J
# 1  B00GZ6TX7E
# 2  B09QZ2RZLV
# 3  B000021Y1B
# 4  B07MMP45FS
# 5  B00EEH3U2K
# 6  B001A33GMU
# 7  B0BV24K2CD
# 8  B00UBRKJFI
# 9  B003C3V6WI
#
#                                                                                                                                                      item_title  \
# 0                              Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch
# 1                                                                                                                                NEW HOLLAND SKYLINE [Xbox 360]
# 2       HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch
# 3                                                                                                                                     Rampage 2: Universal Tour
# 4                                                                                                                     Warner Home Video Lego Jurassic World PS4
# 5                                                                                                  Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]
# 6                                                                                                                                Mysteryville - PC (Jewel case)
# 7  Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case
# 8                                                                                                                             Wolfenstein The Old Blood [ceroZ]
# 9                                                                                       Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]
#
#                                                                                               tags
# 0        [Keyboard Accessory, Mechanical Keyboard, Switch Film, Custom Modding, Gaming Peripheral]
# 1                    [Racing Game, Simulation, Legacy Gaming, Brand Association, Interactive Play]
# 2               [Gaming Headset, Pikachu, Anime Merchandise, Officially Licensed, Audio Accessory]
# 3                                   [Action Game, Retro Gaming, Multiplayer, Destruction, Classic]
# 4              [Action-Adventure, Family-Friendly, Lego Game, Jurassic Park, Cooperative Gameplay]
# 5             [Strategy Game, Turn-Based Combat, Indie Game, Digital Download, Historical Setting]
# 6                                  [Puzzle Game, Mystery, Casual Gaming, Single Player, Adventure]
# 7  [Controller Accessory, Wii-Compatible, Wireless Technology, Multiple Packs, Gaming Accessories]
# 8                [First-Person Shooter, Action, Narrative-Driven, Single Player, Historic Setting]
# 9              [Data Transfer, Console Accessory, Hardware Utility, Storage Solution, Electronics]

# %% [markdown]
# # Get sample items

# %%
train_df = pd.read_parquet("../data/train_features_neg_df.parquet")

# %%
all_items = train_df[args.item_col].unique()
logger.info(f"{len(all_items)=}")
# Out:
# 2024-11-26 21:00:06.509 | INFO     | __main__:<module>:2 - len(all_items)=4630

# %%
all_items_df = metadata_df.loc[lambda df: df[args.item_col].isin(all_items)]

# %%
all_items_df
# Out:
#           main_category                                              title  \
# 2           Video Games   NBA 2K17 - Early Tip Off Edition - PlayStation 4
# 15          Video Games  Warhammer 40,000 Dawn of War Game of the Year ...
# 46          Video Games  Polk Audio Striker Zx Xbox One Gaming Headset ...
# 63          Video Games  The Legend of Heroes: Trails in the Sky - Sony...
# 65          Video Games            Harry Potter: Goblet of Fire - Sony PSP
# ...                 ...                                                ...
# 118437      Video Games                                    Resident Evil 4
# 118457  All Electronics  ivoler Carrying Storage Case for Nintendo Swit...
# 118459      Video Games  EastVita New Charger Dock + 4 x Battery for Ni...
# 118510      Video Games                    Mario & Luigi: Partners In Time
# 118595     Toys & Games             DC Superman Fun Pack - LEGO Dimensions
#
#         average_rating  rating_number  \
# 2                  4.3            223
# 15                 4.0             68
# 46                 3.9            169
# 63                 4.4             91
# 65                 3.6             38
# ...                ...            ...
# 118437             4.6           1133
# 118457             4.8          13702
# 118459             3.9            676
# 118510             4.6            607
# 118595             4.7            436
#
#                                                  features  \
# 2       [The #1 rated NBA video game simulation series...
# 15      [Real-time strategy game based on the popular ...
# 46      [Powered by 40 years of audio heritage and tun...
# 63      [After a brief hiatus since its last release i...
# 65      [All the Magic of the Movie - Characters model...
# ...                                                   ...
# 118437                                                 []
# 118457  [Deluxe Travel Carrying Case. Specially design...
# 118459  [Include: 1x Remote Controller Charger 4 x 280...
# 118510  [Players use the top screen to study the land,...
# 118595  [Brand New in box. The product ships with all ...
#
#                                               description  price  \
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 15      [From the Manufacturer, This Game of The Year ...  29.95
# 46      [Our ProFit Comfort system creates a lightweig...   None
# 63      [Product Description, In the peaceful town of ...  185.0
# 65      [From the Manufacturer, Be Harry Potter in a n...  19.43
# ...                                                   ...    ...
# 118437  [In Resident Evil 4 you'll know a new type of ...  44.98
# 118457                                                 []  26.39
# 118459        [Charger Dock + 4 x Battery for Wii Remote]   None
# 118510  [Mario and Luigi: Partners In Time an insane s...  99.99
# 118595  [When a mysterious and powerful vortex suddenl...   None
#
#                                                    images  \
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 15      {'hi_res': [None, 'https://m.media-amazon.com/...
# 46      {'hi_res': ['https://m.media-amazon.com/images...
# 63      {'hi_res': ['https://m.media-amazon.com/images...
# 65      {'hi_res': [None, 'https://m.media-amazon.com/...
# ...                                                   ...
# 118437  {'hi_res': ['https://m.media-amazon.com/images...
# 118457  {'hi_res': ['https://m.media-amazon.com/images...
# 118459  {'hi_res': ['https://m.media-amazon.com/images...
# 118510  {'hi_res': ['https://m.media-amazon.com/images...
# 118595  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos            store  \
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...               2K
# 15                {'title': [], 'url': [], 'user_id': []}              THQ
# 46                {'title': [], 'url': [], 'user_id': []}       Polk Audio
# 63      {'title': ['The Legend of Heroes: Trails in th...      Xseed Games
# 65                {'title': [], 'url': [], 'user_id': []}  Electronic Arts
# ...                                                   ...              ...
# 118437            {'title': [], 'url': [], 'user_id': []}           Capcom
# 118457            {'title': [], 'url': [], 'user_id': []}           ivoler
# 118459            {'title': [], 'url': [], 'user_id': []}         EastVita
# 118510            {'title': [], 'url': [], 'user_id': []}         Nintendo
# 118595            {'title': [], 'url': [], 'user_id': []}      WARNER BROS
#
#                                                categories  \
# 2                     [Video Games, PlayStation 4, Games]
# 15                               [Video Games, PC, Games]
# 46         [Video Games, Xbox One, Accessories, Headsets]
# 63      [Video Games, Legacy Systems, PlayStation Syst...
# 65      [Purchase Circles, Geography, United States, M...
# ...                                                   ...
# 118437  [Video Games, Legacy Systems, Nintendo Systems...
# 118457  [Video Games, Legacy Systems, Nintendo Systems...
# 118459  [Video Games, Legacy Systems, Nintendo Systems...
# 118510  [Video Games, Legacy Systems, Nintendo Systems...
# 118595  [Video Games, Legacy Systems, PlayStation Syst...
#
#                                                   details parent_asin  \
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 15      {"Release date": "September 20, 2005", "Best S...  B001EYUX4Y
# 46      {"Release date": "October 5, 2014", "Best Sell...  B00OLOQGAY
# 63      {"Release date": "March 29, 2011", "Best Selle...  B004BV5O0U
# 65      {"Release date": "September 8, 2006", "Best Se...  B001ELJEA6
# ...                                                   ...         ...
# 118437  {"Release date": "June 19, 2007", "Best Seller...  B000P46NKC
# 118457  {"Product Dimensions": "11.2 x 4 x 9 inches", ...  B076GYVWRY
# 118459  {"Pricing": "The strikethrough price is the Li...  B004Y2VAVS
# 118510  {"Release date": "November 28, 2005", "Best Se...  B000B8J7K0
# 118595  {"Product Dimensions": "7.99 x 6.77 x 7.4 inch...  B00XUYWTUC
#
#        bought_together subtitle author
# 2                 None     None   None
# 15                None     None   None
# 46                None     None   None
# 63                None     None   None
# 65                None     None   None
# ...                ...      ...    ...
# 118437            None     None   None
# 118457            None     None   None
# 118459            None     None   None
# 118510            None     None   None
# 118595            None     None   None
#
# [4630 rows x 16 columns]

# %% [markdown]
# # Batch extraction

# %%
processed_fp = args.processed_fp
skip_processed = args.skip_processed

# %% [markdown]
# ## Processed outputs

# %%
if not skip_processed and processed_fp is not None and os.path.exists(processed_fp):
    logger.info(f"Loading processed data from {processed_fp}...")
    processed_json = load_extracted(processed_fp)
    processed_df = pd.DataFrame(processed_json)
    to_process_df = all_items_df.loc[
        lambda df: ~df[args.item_col].isin(processed_df[args.item_col])
    ]
    logger.info(
        f"{all_items_df.shape=} - {processed_df.shape=} = {to_process_df.shape=}"
    )
    output_file = processed_fp
else:
    to_process_df = all_items_df.copy()
    output_file = f"{args.notebook_persist_dp}/{args.run_name}.jsonl"

# %% [markdown]
# ## Run

# %%
run_datetime = int(time.time())
run_name = f"run__{args.run_name}__batch__{run_datetime}"
log_file = f"{args.notebook_persist_dp}/{args.run_name}.log"
pipeline_metadata = dict()

logger.add(
    output_file,
    filter=lambda record: "[OUTPUT]" in record["message"],
    level="DEBUG",
    serialize=True,
    mode="a",
)
logger.add(
    log_file,
    filter=lambda record: "[COLLECT]" in record["message"],
    level="ERROR",
    serialize=True,
)
# Out:
# 2

# %%
# Group search queries as batch to send to Gemini API
num_inputs_per_batch = 10
iterator_group_df = (
    to_process_df.reset_index(drop=True)
    .reset_index()
    .assign(group=lambda df: df["index"] // num_inputs_per_batch)
    .groupby(["group"])[[args.item_col, *args.selected_cols]]
    .apply(lambda df: df.to_dict(orient="records"))
    .to_frame("item_metadata")
)
iterator_group_df
# Out:
#                                            item_metadata
# group
# 0      [{'parent_asin': 'B00Z9TLVK0', 'title': 'NBA 2...
# 1      [{'parent_asin': 'B00BN5T30E', 'title': 'Assas...
# 2      [{'parent_asin': 'B00YM7AKLG', 'title': 'FIFA ...
# 3      [{'parent_asin': 'B003QCJLRM', 'title': 'Zumba...
# 4      [{'parent_asin': 'B07BHXMYV6', 'title': 'Valky...
# ...                                                  ...
# 458    [{'parent_asin': 'B001EYUQC8', 'title': '007 Q...
# 459    [{'parent_asin': 'B000Q6J51S', 'title': 'Phoen...
# 460    [{'parent_asin': 'B078S9S2XF', 'title': 'Shant...
# 461    [{'parent_asin': 'B07HPF7PRT', 'title': 'POUND...
# 462    [{'parent_asin': 'B01N6QKT7H', 'title': 'Ninte...
#
# [463 rows x 1 columns]

# %%
input_list = iterator_group_df["item_metadata"].values.tolist()

# %%
if args.testing:
    logger.info(f"testing=True so only process 10 prompts")
    input_list = input_list[:10]
logger.info(f"Number of prompts to be batch-run: {len(input_list)}")
pipeline_metadata["num_prompts_processed"] = len(input_list)
# Out:
# 2024-11-26 21:00:06.708 | INFO     | __main__:<module>:4 - Number of prompts to be batch-run: 463

# %%
max_workers = 4


def retrieve_item_tags_from_llm_wrapper(fn):
    def __wrapper(*args, **kwargs):
        llm_results = fn(*args, **kwargs)
        input_item_metadata = args[0]
        (
            logger.opt(lazy=True)
            .bind(input_item_metadata=input_item_metadata, llm_extracted=llm_results)
            .debug("[OUTPUT] LLM Extracted successfully")
        )
        return llm_results

    return __wrapper


async def retrieve_item_tags_from_llm_async():
    loop = asyncio.get_event_loop()

    # Use a ThreadPoolExecutor to run the functions in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Use list comprehension to submit tasks to the executor
        futures = [
            loop.run_in_executor(
                executor,
                retrieve_item_tags_from_llm_wrapper(retrieve_item_tags_from_llm),
                input_item_metadata,
            )
            for input_item_metadata in input_list
        ]

        # Wait for all tasks to complete
        results = await asyncio.gather(*futures)

    return results

# %%
t0 = time.perf_counter()
logger.debug(f"Outputing to {output_file}...")
try:
    logger.info(
        f"""To monitor the progress, run in a separate CLI: \n```\nwatch -n 0.1 "grep -wF 'LLM Extracted successfully' {output_file} | wc -l"\n```"""
    )
    results = await retrieve_item_tags_from_llm_async()
finally:
    t1 = time.perf_counter()
# Out:
# 2024-11-26 21:00:06.730 | DEBUG    | __main__:<module>:2 - Outputing to /home/dvquys/frostmourne/tmp/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl...
# 2024-11-26 21:00:06.731 | INFO     | __main__:<module>:4 - To monitor the progress, run in a separate CLI:
# ```
# watch -n 0.1 "grep -wF 'LLM Extracted successfully' /home/dvquys/frostmourne/tmp/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl | wc -l"
# ```
# 2024-11-26 21:00:13.001 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:14.423 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:14.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:16.248 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:19.978 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:22.167 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:23.304 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:23.476 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:26.748 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:28.748 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:31.010 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:31.772 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:33.720 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:35.641 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:37.235 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:37.589 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:39.850 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:42.300 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:42.949 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:44.339 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:45.029 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:49.524 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:49.941 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:52.022 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:55.181 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:58.318 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:58.740 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:00:59.505 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:04.479 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:05.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:06.043 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:06.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:13.072 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:13.078 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:15.402 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:17.759 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:19.391 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:20.960 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:21.952 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:23.467 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:27.085 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:27.924 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:30.141 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:31.236 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:34.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:34.501 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:38.012 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:38.974 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:40.791 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:43.947 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:45.859 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:46.382 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:46.738 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:53.172 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:53.354 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:53.402 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:01:58.050 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:00.032 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:00.362 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:00.636 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:04.529 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:06.298 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:07.347 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:08.391 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:11.990 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:12.641 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:15.899 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:15.974 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:19.512 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:20.031 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:22.376 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:24.354 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:26.519 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:28.151 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:29.163 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:31.231 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:33.512 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:34.368 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:35.885 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:39.700 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:39.752 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:39.950 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:43.000 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:45.363 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:46.079 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:47.066 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:48.460 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:50.496 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:53.819 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:54.432 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:54.734 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:02:57.262 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:00.164 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:00.611 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:00.974 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:03.602 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:05.923 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:06.702 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:07.943 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:11.629 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:15.313 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:15.523 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:16.767 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:16.784 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:21.814 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:21.987 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:23.357 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:24.317 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:28.629 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:29.067 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:31.331 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:33.633 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:35.215 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:36.204 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:39.152 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:41.318 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:42.899 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:45.368 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:46.833 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:48.001 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:49.620 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:51.808 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:53.438 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:53.941 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:55.869 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:58.054 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:59.779 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:03:59.999 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:05.373 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:05.390 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:06.039 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:10.637 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:11.482 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:13.193 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:13.665 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:17.234 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:18.451 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:20.061 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:21.095 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:23.680 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:25.127 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:26.647 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:27.962 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:30.660 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:32.376 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:34.314 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:35.027 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:37.883 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:37.930 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:41.685 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:41.959 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:44.295 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:45.323 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:47.901 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:48.512 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:51.684 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:51.718 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:54.326 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:55.293 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:57.673 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:04:58.113 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:00.239 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:01.714 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:03.384 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:04.372 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:07.048 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:07.063 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:11.426 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:12.317 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:13.807 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:14.149 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:19.006 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:20.132 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:20.337 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:21.475 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:25.664 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:25.691 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:25.988 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:28.662 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:32.133 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:32.702 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:32.950 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:35.698 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:37.441 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:39.102 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:41.616 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:41.931 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:44.212 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:46.301 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:47.114 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:50.270 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:50.415 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:53.866 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:54.824 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:56.101 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:05:57.205 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:00.650 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:01.954 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:02.236 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:03.785 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:06.462 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:07.797 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:08.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:10.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:14.243 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:15.661 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:16.755 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:17.014 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:22.261 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:22.487 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:22.561 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:22.573 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:28.901 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:29.730 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:29.745 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:29.771 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:36.597 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:36.641 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:37.508 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:38.035 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:42.700 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:43.332 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:44.389 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:44.602 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:50.207 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:50.677 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:51.162 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:51.384 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:57.042 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:57.418 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:57.787 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:06:58.677 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:04.018 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:04.930 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:05.179 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:06.432 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:10.713 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:10.849 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:12.015 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:12.103 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:17.290 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:17.748 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:18.674 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:20.155 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:24.504 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:24.710 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:24.968 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:27.681 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:30.745 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:32.534 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:33.936 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:34.191 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:36.061 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:37.373 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:40.398 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:40.551 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:42.391 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:42.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:46.315 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:46.835 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:49.356 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:49.433 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:53.001 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:53.304 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:55.235 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:55.411 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:07:59.184 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:00.219 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:01.920 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:02.161 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:06.485 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:07.327 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:07.731 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:09.114 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:11.671 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:13.600 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:14.081 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:14.279 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:19.384 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:20.237 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:20.744 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:22.777 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:25.955 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:26.044 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:26.691 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:29.089 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:31.703 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:32.735 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:33.998 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:35.206 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:37.730 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:39.343 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:39.585 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:41.324 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:43.873 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:44.034 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:45.838 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:47.801 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:50.517 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:50.638 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:51.389 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:56.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:57.172 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:57.284 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:08:57.521 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:02.599 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:03.157 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:03.481 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:04.063 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:08.751 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:09.680 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:09.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:11.324 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:14.000 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:16.437 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:17.866 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:18.238 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:20.101 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:22.028 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:23.425 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:27.827 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:30.966 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:32.739 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:32.881 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:38.020 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:41.613 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:43.396 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:44.553 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:49.351 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:51.347 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:53.400 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:54.892 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:09:56.878 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:00.049 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:02.692 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:06.170 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:08.330 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:09.224 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:11.991 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:16.520 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:16.870 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:17.488 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:19.083 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:23.691 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:24.370 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:24.919 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:25.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:29.583 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:30.298 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:32.123 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:33.146 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:36.013 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:37.691 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:37.707 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:40.354 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:41.114 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:43.651 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:43.843 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:45.157 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:47.851 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:49.269 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:49.843 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:51.371 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:53.595 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:56.104 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:57.905 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:58.180 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:10:58.499 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:01.019 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:03.342 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:04.529 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:04.720 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:07.713 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:10.565 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:11.348 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:12.822 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:12.839 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:16.441 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:17.694 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:18.581 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:19.235 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:23.187 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:24.794 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:25.120 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:25.804 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:29.591 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:29.841 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:31.927 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:32.062 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:35.760 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:36.018 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:38.853 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:39.376 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:40.434 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:42.311 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:46.097 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:47.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:47.368 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:48.721 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:52.506 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:53.328 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:54.095 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:55.497 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:58.650 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:11:59.227 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:00.028 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:00.297 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:04.757 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:04.774 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:06.014 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:06.439 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:09.292 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:11.132 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:12.183 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:14.243 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:14.337 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:16.111 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:18.913 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:20.174 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:20.434 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:22.382 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:25.339 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:26.175 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:26.372 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:27.132 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:30.279 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:31.118 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:31.701 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:33.781 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:36.284 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:36.331 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:38.047 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:41.190 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:41.580 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:43.265 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:44.213 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:46.452 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:47.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:48.986 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:50.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:52.946 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:54.175 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:55.501 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:55.649 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:58.818 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:12:59.616 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:01.449 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:02.165 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:04.879 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:06.132 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:08.312 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:08.931 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:10.920 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:11.055 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:14.564 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:15.279 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:16.569 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:17.374 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:20.146 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:21.470 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:23.047 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:23.312 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-26 21:13:25.696 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully

# %%
logger.info(
    f"Run duration: {t1 - t0:,.2f}s, on avg. {(t1-t0)/len(input_list):,.2f}s per batch"
)
# Out:
# 2024-11-26 21:13:25.728 | INFO     | __main__:<module>:1 - Run duration: 798.97s, on avg. 1.73s per batch

# %%
logger.info(f"Checking output...")
output_json = load_extracted(output_file)
# Out:
# 2024-11-26 21:13:25.738 | INFO     | __main__:<module>:1 - Checking output...

# %%
extracted_df = pd.DataFrame(output_json)
with pd.option_context("display.max_colwidth", None):
    display(extracted_df)
# Out:
#      parent_asin  \
# 0     B00BN5T30E
# 1     B07KXS41QL
# 2     B00XY0IVK4
# 3     B078GLDBZX
# 4     B01GY35HKE
# ...          ...
# 4623  B000P46NKC
# 4624  B076GYVWRY
# 4625  B004Y2VAVS
# 4626  B000B8J7K0
# 4627  B00XUYWTUC
#
#                                                                                                                                                                                                    item_title  \
# 0                                                                                                                                                                         Assassin's Creed IV Black Flag - PC
# 1                                                                     Nyko Charge Block Duo - 2 Port Controller Charging Station with Patented Charging Dongles and Micro-USB/AC Power Cord for PlayStation 4
# 2                                                                                                                                                                                      NHL 16 - PlayStation 4
# 3                                                                                                                               Street Fighter 30th Anniversary Collection - Nintendo Switch Standard Edition
# 4                                                                                                                                                                     Mass Effect Andromeda Deluxe - Xbox One
# ...                                                                                                                                                                                                       ...
# 4623                                                                                                                                                                                          Resident Evil 4
# 4624  ivoler Carrying Storage Case for Nintendo Switch/For Switch OLED Model (2021),Portable Travel All Protective Hard Messenger Bag Soft Lining 18Games for Switch Console Pro Controller Accessories Black
# 4625                                                                                                                                          EastVita New Charger Dock + 4 x Battery for Nintendo Wii Remote
# 4626                                                                                                                                                                          Mario & Luigi: Partners In Time
# 4627                                                                                                                                                                   DC Superman Fun Pack - LEGO Dimensions
#
#                                                                                  tags
# 0     [Action-Adventure, Open World, Historical Fiction, Single Player, Pirate Theme]
# 1      [Charging Station, Dual Charger, Controller Accessory, Micro-USB, Convenience]
# 2                   [Sports, Hockey, Multiplayer, Realistic Gameplay, Franchise Mode]
# 3               [Fighting, Multiplayer, Classic Games, Arcade Mode, Retro Collection]
# 4            [Action RPG, Sci-Fi, Narrative Driven, Space Exploration, Single Player]
# ...                                                                               ...
# 4623           [Survival Horror, Action-adventure, Classic, Legacy, Narrative-driven]
# 4624  [Storage Case, Travel Accessory, Protective Case, Switch Accessories, Portable]
# 4625         [Charging Dock, Battery Pack, Wii Remote, Accessory Bundle, Convenience]
# 4626    [Role-playing Game, Platformer, Nintendo DS, Adventure, Cooperative Gameplay]
# 4627                 [LEGO, Interactive Figures, Cross-platform, Fun Pack, DC Comics]
#
# [4628 rows x 3 columns]

# %% [markdown]
# # Persist

# %%
output_fp = "../data/item_tags_from_llm.parquet"
extracted_df.to_parquet(output_fp, index=False)
