# %% [markdown]
# # LLM Playground: Tagging items

# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio
import concurrent.futures
import os
import sys
import time
from typing import List

import pandas as pd
from datasets import load_dataset
from dotenv import load_dotenv
from loguru import logger
from openai import OpenAI
from pydantic import BaseModel

load_dotenv()

sys.path.insert(0, "..")

from llm.tagger import PROMPT as ITEM_TAGGING_PROMPT
from llm.tagger import SYSTEM_PROMPT
from llm.utils import load_extracted

# %% [markdown]
# # Controller

# %%
class Args(BaseModel):
    testing: bool = False
    run_name: str = "040-llm-tag-items"
    notebook_persist_dp: str = None
    random_seed: int = 41

    user_col: str = "user_id"
    item_col: str = "parent_asin"
    rating_col: str = "rating"
    timestamp_col: str = "timestamp"

    selected_cols: List[str] = ["title", "categories"]

    skip_processed: bool = False
    # processed_fp: str = "/Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/run__040-llm-tag-items__batch__1731068753.jsonl"
    processed_fp: str = None

    def init(self):
        self.notebook_persist_dp = os.path.abspath(f"data/{self.run_name}")
        os.makedirs(self.notebook_persist_dp, exist_ok=True)

        return self


args = Args().init()

print(args.model_dump_json(indent=2))
# Out:
# {
#   "testing": false,
#   "run_name": "040-llm-tag-items",
#   "notebook_persist_dp": "/Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items",
#   "random_seed": 41,
#   "user_col": "user_id",
#   "item_col": "parent_asin",
#   "rating_col": "rating",
#   "timestamp_col": "timestamp",
#   "selected_cols": [
#     "title",
#     "categories"
#   ],
#   "skip_processed": false,
#   "processed_fp": null
# }

# %% [markdown]
# # Load data

# %%
metadata_raw = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Video_Games", trust_remote_code=True
)
metadata_df = metadata_raw["full"].to_pandas()
metadata_df
# Out:
#                     main_category  \
# 0                     Video Games
# 1                     Video Games
# 2                     Video Games
# 3                     Video Games
# 4                     Video Games
# ...                           ...
# 137264                       None
# 137265                Video Games
# 137266  Cell Phones & Accessories
# 137267                       None
# 137268                       None
#
#                                                     title  average_rating  \
# 0                          Dash 8-300 Professional Add-On             5.0
# 1                       Phantasmagoria: A Puzzle of Flesh             4.1
# 2        NBA 2K17 - Early Tip Off Edition - PlayStation 4             4.3
# 3       Nintendo Selects: The Legend of Zelda Ocarina ...             4.9
# 4        Thrustmaster Elite Fitness Pack for Nintendo Wii             3.0
# ...                                                   ...             ...
# 137264  Story of Seasons: Pioneers Of Olive Town (Nint...             4.5
# 137265           MotoGP 18 (PC DVD) UK IMPORT REGION FREE             4.0
# 137266  Century Accessory Soft Silicone Protective Ski...             2.9
# 137267  Hasbro Interactive Mr. Potato Head Activity Pa...             3.9
# 137268                                  Worms: Armageddon             4.3
#
#         rating_number                                           features  \
# 0                   1  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                  18                                       [Windows 95]
# 2                 223  [The #1 rated NBA video game simulation series...
# 3                  22  [Authentic Nintendo Selects: The Legend of Zel...
# 4                   3  [Includes (9) Total Accessories, Pedometer, Wi...
# ...               ...                                                ...
# 137264            397  [A wild world of discovery - tame the wilderne...
# 137265              1  [Brand new game engine - MotoGP18 has been reb...
# 137266             19  [Easy access to all buttons, controls and port...
# 137267              5                                                 []
# 137268             13                                                 []
#
#                                               description  price  \
# 0       [The Dash 8-300 Professional Add-On lets you p...   None
# 1                                                      []   None
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 3                                                      []  37.42
# 4       [The Thrustmaster Motion Plus Elite Fitness Pa...   None
# ...                                                   ...    ...
# 137264  [Product Description, Inspired by Tales of you...  31.04
# 137265  [Become the champion of the 2018 MotoGP Season...   None
# 137266  [This soft case cover will add a splash of col...   None
# 137267  [Amazon.com, Everyone's favorite master-of-dis...   None
# 137268  [Product Description, Do you ever wonder what ...   None
#
#                                                    images  \
# 0       {'hi_res': [None], 'large': ['https://m.media-...
# 1       {'hi_res': ['https://m.media-amazon.com/images...
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 3       {'hi_res': ['https://m.media-amazon.com/images...
# 4       {'hi_res': [None, None, None, None, None, None...
# ...                                                   ...
# 137264  {'hi_res': ['https://m.media-amazon.com/images...
# 137265  {'hi_res': ['https://m.media-amazon.com/images...
# 137266  {'hi_res': ['https://m.media-amazon.com/images...
# 137267  {'hi_res': [None, 'https://m.media-amazon.com/...
# 137268  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos              store  \
# 0                 {'title': [], 'url': [], 'user_id': []}           Aerosoft
# 1                 {'title': [], 'url': [], 'user_id': []}             Sierra
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...                 2K
# 3                 {'title': [], 'url': [], 'user_id': []}     Amazon Renewed
# 4                 {'title': [], 'url': [], 'user_id': []}       THRUSTMASTER
# ...                                                   ...                ...
# 137264            {'title': [], 'url': [], 'user_id': []}   Marvelous Europe
# 137265            {'title': [], 'url': [], 'user_id': []}          Milestone
# 137266            {'title': [], 'url': [], 'user_id': []}  Century Accessory
# 137267            {'title': [], 'url': [], 'user_id': []}             Hasbro
# 137268            {'title': [], 'url': [], 'user_id': []}             Hasbro
#
#                                                categories  \
# 0                                [Video Games, PC, Games]
# 1                                [Video Games, PC, Games]
# 2                     [Video Games, PlayStation 4, Games]
# 3       [Video Games, Legacy Systems, Nintendo Systems...
# 4       [Video Games, Legacy Systems, Nintendo Systems...
# ...                                                   ...
# 137264              [Video Games, Nintendo Switch, Games]
# 137265             [Video Games, Game Genre of the Month]
# 137266  [Video Games, Legacy Systems, Xbox Systems, Xb...
# 137267                           [Video Games, PC, Games]
# 137268  [Video Games, Legacy Systems, Sega Systems, Se...
#
#                                                   details parent_asin  \
# 0       {"Pricing": "The strikethrough price is the Li...  B000FH0MHO
# 1       {"Best Sellers Rank": {"Video Games": 137612, ...  B00069EVOG
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 3       {"Best Sellers Rank": {"Video Games": 51019, "...  B07SZJZV88
# 4       {"Release date": "November 1, 2009", "Pricing"...  B002WH4ZJG
# ...                                                   ...         ...
# 137264  {"Release date": "March 26, 2021", "Best Selle...  B09XQJS4CZ
# 137265  {"Pricing": "The strikethrough price is the Li...  B07DGPTGNV
# 137266  {"Package Dimensions": "2.76 x 2.76 x 0.2 inch...  B00HUWCQBW
# 137267  {"Release date": "July 24, 1999", "Best Seller...  B00002S9MH
# 137268  {"Release date": "December 3, 1999", "Best Sel...  B00001OX4N
#
#        bought_together subtitle author
# 0                 None     None   None
# 1                 None     None   None
# 2                 None     None   None
# 3                 None     None   None
# 4                 None     None   None
# ...                ...      ...    ...
# 137264            None     None   None
# 137265            None     None   None
# 137266            None     None   None
# 137267            None     None   None
# 137268            None     None   None
#
# [137269 rows x 16 columns]

# %%
metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")
# Out:
# [{'parent_asin': 'B09ZYFYT5J',
#   'title': 'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch',
#   'categories': array(['Video Games', 'PC', 'Accessories', 'Gaming Keyboards'],
#         dtype=object)},
#  {'parent_asin': 'B00GZ6TX7E',
#   'title': 'NEW HOLLAND SKYLINE [Xbox 360]',
#   'categories': array(['Video Games', 'Legacy Systems', 'Xbox Systems', 'Xbox 360',
#          'Interactive Gaming Figures'], dtype=object)},
#  {'parent_asin': 'B09QZ2RZLV',
#   'title': 'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch',
#   'categories': array(['Video Games', 'Nintendo Switch', 'Accessories'], dtype=object)},
#  {'parent_asin': 'B000021Y1B',
#   'title': 'Rampage 2: Universal Tour',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Nintendo 64',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B07MMP45FS',
#   'title': 'Warner Home Video Lego Jurassic World PS4',
#   'categories': array(['Video Games', 'PlayStation 4', 'Games'], dtype=object)},
#  {'parent_asin': 'B00EEH3U2K',
#   'title': 'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B001A33GMU',
#   'title': 'Mysteryville - PC (Jewel case)',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B0BV24K2CD',
#   'title': 'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Wii',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B00UBRKJFI',
#   'title': 'Wolfenstein The Old Blood\u3000[ceroZ]',
#   'categories': array([], dtype=object)},
#  {'parent_asin': 'B003C3V6WI',
#   'title': 'Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]',
#   'categories': array([], dtype=object)}]

# %% [markdown]
# # Call OpenAI to get tags

# %%
sampled_items = metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")

# %%
prompt = ITEM_TAGGING_PROMPT.format(input_list=sampled_items)
prompt
# Out:
# '\nFor each of the following items, generate a set of tags that capture the main features, target audience, platform compatibility, and item type (e.g., accessory, game, hardware).\n\nReturn the output as a list of JSON objects, where each object includes the original item `title`, `parent_asin`, and a list of tags.\n\nFocus on adding tags that help shoppers easily find these items based on genre, brand associations, and product functionality.\n\nIf possible, add new information that is not obvious from the item title.\n\nDo not include the tags that are similar to those in the input categories, for example do not include tags about gaming platforms as output.\n\n<EXAMPLE>\n\nExample item titles with JSON input and output:\n\nInput:  \n[\n    { "parent_asin": "B09ZYFYT5J", "title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch" },\n    { "parent_asin": "B00GZ6TX7E", "title": "NEW HOLLAND SKYLINE [Xbox 360]" },\n    { "parent_asin": "B09QZ2RZLV", "title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch" }\n]\n\nOutput:  \n[\n    {\n        "parent_asin": "B09ZYFYT5J",\n        "item_title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch",\n        "tags": ["Keyboard Accessory", "Cherry MX", "Mechanical Keyboard", "Switch Film", "Gateron", "Repair"]\n    },\n    {\n        "parent_asin": "B00GZ6TX7E",\n        "item_title": "NEW HOLLAND SKYLINE [Xbox 360]",\n        "tags": ["Racing", "NEW HOLLAND", "Skyline", "Retro"]\n    },\n    {\n        "parent_asin": "B09QZ2RZLV",\n        "item_title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch",\n        "tags": ["Headset", "Nintendo Switch", "Switch Lite", "Pikachu", "Pokemon", "Gaming Accessory"]\n    }\n]\n\n</EXAMPLE>\n\nInput:\n[{\'parent_asin\': \'B09ZYFYT5J\', \'title\': \'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch\', \'categories\': array([\'Video Games\', \'PC\', \'Accessories\', \'Gaming Keyboards\'],\n      dtype=object)}, {\'parent_asin\': \'B00GZ6TX7E\', \'title\': \'NEW HOLLAND SKYLINE [Xbox 360]\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Xbox Systems\', \'Xbox 360\',\n       \'Interactive Gaming Figures\'], dtype=object)}, {\'parent_asin\': \'B09QZ2RZLV\', \'title\': \'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch\', \'categories\': array([\'Video Games\', \'Nintendo Switch\', \'Accessories\'], dtype=object)}, {\'parent_asin\': \'B000021Y1B\', \'title\': \'Rampage 2: Universal Tour\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Nintendo 64\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B07MMP45FS\', \'title\': \'Warner Home Video Lego Jurassic World PS4\', \'categories\': array([\'Video Games\', \'PlayStation 4\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B00EEH3U2K\', \'title\': \'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B001A33GMU\', \'title\': \'Mysteryville - PC (Jewel case)\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B0BV24K2CD\', \'title\': \'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Wii\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B00UBRKJFI ...

# %%
client = OpenAI()


# Define the structured output format using Pydantic for a single item
class ItemTag(BaseModel):
    parent_asin: str
    item_title: str
    tags: List[str]


# Define the output format to wrap the list of items within an object
class ItemTaggingOutput(BaseModel):
    items: List[ItemTag]  # Wrap list in an "items" field

# %%
def retrieve_item_tags_from_llm(item_metadata: List[dict]):
    prompt = ITEM_TAGGING_PROMPT.format(input_list=item_metadata)

    completion = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": SYSTEM_PROMPT,
            },
            {"role": "user", "content": prompt},
        ],
        response_format=ItemTaggingOutput,
    )

    tagged_items = completion.choices[0].message.parsed

    return tagged_items.dict()["items"]

# %%
extracted_tags = retrieve_item_tags_from_llm(sampled_items)
with pd.option_context("display.max_colwidth", None):
    display(pd.DataFrame(extracted_tags))
# Out:
#   parent_asin  \
# 0  B09ZYFYT5J
# 1  B00GZ6TX7E
# 2  B09QZ2RZLV
# 3  B000021Y1B
# 4  B07MMP45FS
# 5  B00EEH3U2K
# 6  B001A33GMU
# 7  B0BV24K2CD
# 8  B00UBRKJFI
# 9  B003C3V6WI
#
#                                                                                                                                                      item_title  \
# 0                              Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch
# 1                                                                                                                                NEW HOLLAND SKYLINE [Xbox 360]
# 2       HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch
# 3                                                                                                                                     Rampage 2: Universal Tour
# 4                                                                                                                     Warner Home Video Lego Jurassic World PS4
# 5                                                                                                  Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]
# 6                                                                                                                                Mysteryville - PC (Jewel case)
# 7  Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case
# 8                                                                                                                             Wolfenstein The Old Blood　[ceroZ]
# 9                                                                                       Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]
#
#                                                                                                    tags
# 0  [Keyboard Accessory, Cherry MX, Mechanical Keyboard, Switch Film, Gaming Customization, Repair Tool]
# 1                                  [Racing, NEW HOLLAND, Skyline, Vintage, Simulation, Family-Friendly]
# 2                      [Headset, Gaming Accessory, Pikachu, Pokemon, Official Merchandise, Multiplayer]
# 3                                  [Action, Legacy Game, Nintendo 64, Multiplayer, Destruction, Arcade]
# 4                        [Action-Adventure, Lego Series, Jurassic Park, Co-op, Family-Friendly, Puzzle]
# 5                      [Indie Game, Turn-Based Strategy, Online Code, Strategy, Fantasy, Single Player]
# 6                                        [Puzzle, Adventure, Casual Game, PC, Mystery, Point-and-Click]
# 7                       [Controller, Wii Accessory, Replacement, Wireless, Gaming Accessory, Ergonomic]
# 8                               [First-Person Shooter, Action, Single Player, Stealth, Retro, Violence]
# 9                                   [Data Transfer, Xbox 360, Accessory, Electronics, Utility, Storage]

# %% [markdown]
# # Get sample items

# %%
train_df = pd.read_parquet("../data/train_features_neg_df.parquet")

# %%
all_items = train_df[args.item_col].unique()
logger.info(f"{len(all_items)=}")
# Out:
# 2024-11-08 23:31:58.863 | INFO     | __main__:<module>:2 - len(all_items)=4630

# %%
all_items_df = metadata_df.loc[lambda df: df[args.item_col].isin(all_items)]

# %%
all_items_df
# Out:
#           main_category                                              title  \
# 2           Video Games   NBA 2K17 - Early Tip Off Edition - PlayStation 4
# 15          Video Games  Warhammer 40,000 Dawn of War Game of the Year ...
# 46          Video Games  Polk Audio Striker Zx Xbox One Gaming Headset ...
# 63          Video Games  The Legend of Heroes: Trails in the Sky - Sony...
# 65          Video Games            Harry Potter: Goblet of Fire - Sony PSP
# ...                 ...                                                ...
# 118437      Video Games                                    Resident Evil 4
# 118457  All Electronics  ivoler Carrying Storage Case for Nintendo Swit...
# 118459      Video Games  EastVita New Charger Dock + 4 x Battery for Ni...
# 118510      Video Games                    Mario & Luigi: Partners In Time
# 118595     Toys & Games             DC Superman Fun Pack - LEGO Dimensions
#
#         average_rating  rating_number  \
# 2                  4.3            223
# 15                 4.0             68
# 46                 3.9            169
# 63                 4.4             91
# 65                 3.6             38
# ...                ...            ...
# 118437             4.6           1133
# 118457             4.8          13702
# 118459             3.9            676
# 118510             4.6            607
# 118595             4.7            436
#
#                                                  features  \
# 2       [The #1 rated NBA video game simulation series...
# 15      [Real-time strategy game based on the popular ...
# 46      [Powered by 40 years of audio heritage and tun...
# 63      [After a brief hiatus since its last release i...
# 65      [All the Magic of the Movie - Characters model...
# ...                                                   ...
# 118437                                                 []
# 118457  [Deluxe Travel Carrying Case. Specially design...
# 118459  [Include: 1x Remote Controller Charger 4 x 280...
# 118510  [Players use the top screen to study the land,...
# 118595  [Brand New in box. The product ships with all ...
#
#                                               description  price  \
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 15      [From the Manufacturer, This Game of The Year ...  29.95
# 46      [Our ProFit Comfort system creates a lightweig...   None
# 63      [Product Description, In the peaceful town of ...  185.0
# 65      [From the Manufacturer, Be Harry Potter in a n...  19.43
# ...                                                   ...    ...
# 118437  [In Resident Evil 4 you'll know a new type of ...  44.98
# 118457                                                 []  26.39
# 118459        [Charger Dock + 4 x Battery for Wii Remote]   None
# 118510  [Mario and Luigi: Partners In Time an insane s...  99.99
# 118595  [When a mysterious and powerful vortex suddenl...   None
#
#                                                    images  \
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 15      {'hi_res': [None, 'https://m.media-amazon.com/...
# 46      {'hi_res': ['https://m.media-amazon.com/images...
# 63      {'hi_res': ['https://m.media-amazon.com/images...
# 65      {'hi_res': [None, 'https://m.media-amazon.com/...
# ...                                                   ...
# 118437  {'hi_res': ['https://m.media-amazon.com/images...
# 118457  {'hi_res': ['https://m.media-amazon.com/images...
# 118459  {'hi_res': ['https://m.media-amazon.com/images...
# 118510  {'hi_res': ['https://m.media-amazon.com/images...
# 118595  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos            store  \
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...               2K
# 15                {'title': [], 'url': [], 'user_id': []}              THQ
# 46                {'title': [], 'url': [], 'user_id': []}       Polk Audio
# 63      {'title': ['The Legend of Heroes: Trails in th...      Xseed Games
# 65                {'title': [], 'url': [], 'user_id': []}  Electronic Arts
# ...                                                   ...              ...
# 118437            {'title': [], 'url': [], 'user_id': []}           Capcom
# 118457            {'title': [], 'url': [], 'user_id': []}           ivoler
# 118459            {'title': [], 'url': [], 'user_id': []}         EastVita
# 118510            {'title': [], 'url': [], 'user_id': []}         Nintendo
# 118595            {'title': [], 'url': [], 'user_id': []}      WARNER BROS
#
#                                                categories  \
# 2                     [Video Games, PlayStation 4, Games]
# 15                               [Video Games, PC, Games]
# 46         [Video Games, Xbox One, Accessories, Headsets]
# 63      [Video Games, Legacy Systems, PlayStation Syst...
# 65      [Purchase Circles, Geography, United States, M...
# ...                                                   ...
# 118437  [Video Games, Legacy Systems, Nintendo Systems...
# 118457  [Video Games, Legacy Systems, Nintendo Systems...
# 118459  [Video Games, Legacy Systems, Nintendo Systems...
# 118510  [Video Games, Legacy Systems, Nintendo Systems...
# 118595  [Video Games, Legacy Systems, PlayStation Syst...
#
#                                                   details parent_asin  \
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 15      {"Release date": "September 20, 2005", "Best S...  B001EYUX4Y
# 46      {"Release date": "October 5, 2014", "Best Sell...  B00OLOQGAY
# 63      {"Release date": "March 29, 2011", "Best Selle...  B004BV5O0U
# 65      {"Release date": "September 8, 2006", "Best Se...  B001ELJEA6
# ...                                                   ...         ...
# 118437  {"Release date": "June 19, 2007", "Best Seller...  B000P46NKC
# 118457  {"Product Dimensions": "11.2 x 4 x 9 inches", ...  B076GYVWRY
# 118459  {"Pricing": "The strikethrough price is the Li...  B004Y2VAVS
# 118510  {"Release date": "November 28, 2005", "Best Se...  B000B8J7K0
# 118595  {"Product Dimensions": "7.99 x 6.77 x 7.4 inch...  B00XUYWTUC
#
#        bought_together subtitle author
# 2                 None     None   None
# 15                None     None   None
# 46                None     None   None
# 63                None     None   None
# 65                None     None   None
# ...                ...      ...    ...
# 118437            None     None   None
# 118457            None     None   None
# 118459            None     None   None
# 118510            None     None   None
# 118595            None     None   None
#
# [4630 rows x 16 columns]

# %% [markdown]
# # Batch extraction

# %%
processed_fp = args.processed_fp
skip_processed = args.skip_processed

# %% [markdown]
# ## Processed outputs

# %%
if not skip_processed and processed_fp is not None and os.path.exists(processed_fp):
    logger.info(f"Loading processed data from {processed_fp}...")
    processed_json = load_extracted(processed_fp)
    processed_df = pd.DataFrame(processed_json)
    to_process_df = all_items_df.loc[
        lambda df: ~df[args.item_col].isin(processed_df[args.item_col])
    ]
    logger.info(
        f"{all_items_df.shape=} - {processed_df.shape=} = {to_process_df.shape=}"
    )
    output_file = processed_fp
else:
    to_process_df = all_items_df.copy()
    output_file = f"{args.notebook_persist_dp}/{args.run_name}.jsonl"

# %% [markdown]
# ## Run

# %%
run_datetime = int(time.time())
run_name = f"run__{args.run_name}__batch__{run_datetime}"
log_file = f"{args.notebook_persist_dp}/{args.run_name}.log"
pipeline_metadata = dict()

logger.add(
    output_file,
    filter=lambda record: "[OUTPUT]" in record["message"],
    level="DEBUG",
    serialize=True,
    mode="a",
)
logger.add(
    log_file,
    filter=lambda record: "[COLLECT]" in record["message"],
    level="ERROR",
    serialize=True,
)
# Out:
# 2

# %%
# Group search queries as batch to send to Gemini API
num_inputs_per_batch = 10
iterator_group_df = (
    to_process_df.reset_index(drop=True)
    .reset_index()
    .assign(group=lambda df: df["index"] // num_inputs_per_batch)
    .groupby(["group"])[[args.item_col, *args.selected_cols]]
    .apply(lambda df: df.to_dict(orient="records"))
    .to_frame("item_metadata")
)
iterator_group_df
# Out:
#                                            item_metadata
# group
# 0      [{'parent_asin': 'B00Z9TLVK0', 'title': 'NBA 2...
# 1      [{'parent_asin': 'B00BN5T30E', 'title': 'Assas...
# 2      [{'parent_asin': 'B00YM7AKLG', 'title': 'FIFA ...
# 3      [{'parent_asin': 'B003QCJLRM', 'title': 'Zumba...
# 4      [{'parent_asin': 'B07BHXMYV6', 'title': 'Valky...
# ...                                                  ...
# 458    [{'parent_asin': 'B001EYUQC8', 'title': '007 Q...
# 459    [{'parent_asin': 'B000Q6J51S', 'title': 'Phoen...
# 460    [{'parent_asin': 'B078S9S2XF', 'title': 'Shant...
# 461    [{'parent_asin': 'B07HPF7PRT', 'title': 'POUND...
# 462    [{'parent_asin': 'B01N6QKT7H', 'title': 'Ninte...
#
# [463 rows x 1 columns]

# %%
input_list = iterator_group_df["item_metadata"].values.tolist()

# %%
if args.testing:
    logger.info(f"testing=True so only process 10 prompts")
    input_list = input_list[:10]
logger.info(f"Number of prompts to be batch-run: {len(input_list)}")
pipeline_metadata["num_prompts_processed"] = len(input_list)
# Out:
# 2024-11-08 23:31:59.096 | INFO     | __main__:<module>:4 - Number of prompts to be batch-run: 463

# %%
max_workers = 4


def retrieve_item_tags_from_llm_wrapper(fn):
    def __wrapper(*args, **kwargs):
        llm_results = fn(*args, **kwargs)
        input_item_metadata = args[0]
        (
            logger.opt(lazy=True)
            .bind(input_item_metadata=input_item_metadata, llm_extracted=llm_results)
            .debug("[OUTPUT] LLM Extracted successfully")
        )
        return llm_results

    return __wrapper


async def retrieve_item_tags_from_llm_async():
    loop = asyncio.get_event_loop()

    # Use a ThreadPoolExecutor to run the functions in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Use list comprehension to submit tasks to the executor
        futures = [
            loop.run_in_executor(
                executor,
                retrieve_item_tags_from_llm_wrapper(retrieve_item_tags_from_llm),
                input_item_metadata,
            )
            for input_item_metadata in input_list
        ]

        # Wait for all tasks to complete
        results = await asyncio.gather(*futures)

    return results

# %%
t0 = time.perf_counter()
logger.debug(f"Outputing to {output_file}...")
try:
    logger.info(
        f"""To monitor the progress, run in a separate CLI: \n```\nwatch -n 0.1 "grep -wF 'LLM Extracted successfully' {output_file} | wc -l"\n```"""
    )
    results = await retrieve_item_tags_from_llm_async()
finally:
    t1 = time.perf_counter()
# Out:
# 2024-11-08 23:31:59.136 | DEBUG    | __main__:<module>:2 - Outputing to /Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl...
# 2024-11-08 23:31:59.137 | INFO     | __main__:<module>:4 - To monitor the progress, run in a separate CLI:
# ```
# watch -n 0.1 "grep -wF 'LLM Extracted successfully' /Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl | wc -l"
# ```
# 2024-11-08 23:32:03.889 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:04.806 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:05.269 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:05.360 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:09.750 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:10.553 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:10.912 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:11.536 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:15.010 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:16.277 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:16.741 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:17.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:20.260 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:21.216 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:21.834 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:23.230 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:26.120 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:26.367 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:26.795 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:29.140 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:31.608 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:31.960 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:32.020 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:34.684 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:36.749 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:37.507 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:37.528 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:40.452 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:42.982 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:43.521 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:43.776 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:45.053 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:49.553 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:49.714 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:49.816 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:50.408 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:53.284 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:54.490 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:54.961 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:55.610 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:59.009 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:32:59.946 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:00.096 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:00.657 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:04.150 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:05.572 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:06.296 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:06.560 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:09.278 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:10.755 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:11.155 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:12.526 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:15.114 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:15.681 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:16.088 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:18.564 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:20.749 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:21.714 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:21.921 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:23.520 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:25.162 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:27.497 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:27.788 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:29.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:31.032 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:33.019 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:33.031 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:35.147 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:36.590 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:38.888 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:39.425 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:40.524 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:41.132 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:43.432 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:43.895 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:45.029 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:46.842 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:49.040 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:49.290 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:50.605 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:52.015 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:55.178 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:55.568 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:55.697 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:33:57.435 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:00.472 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:01.038 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:01.488 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:02.817 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:04.661 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:07.057 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:07.150 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:08.885 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:10.134 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:13.446 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:13.591 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:13.980 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:15.352 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:18.383 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:18.807 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:19.632 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:20.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:23.299 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:23.993 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:25.007 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:26.088 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:27.772 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:29.946 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:30.807 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:31.173 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:32.686 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:35.584 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:35.726 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:36.949 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:37.433 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:40.795 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:42.109 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:42.525 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:42.534 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:46.696 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:46.996 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:47.093 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:52.144 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:52.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:52.587 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:57.388 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:57.639 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:57.945 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:34:58.305 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:02.465 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:02.956 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:03.227 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:03.385 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:08.628 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:09.835 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:09.867 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:11.298 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:15.439 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:15.702 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:16.178 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:16.826 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:20.521 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:20.897 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:22.128 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:25.957 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:26.134 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:27.835 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:30.216 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:30.251 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:31.220 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:33.274 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:35.356 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:35.956 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:36.862 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:38.897 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:39.712 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:41.733 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:42.139 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:44.970 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:45.342 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:46.805 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:48.620 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:51.059 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:51.486 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:52.516 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:54.737 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:56.930 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:56.934 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:35:58.223 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:00.818 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:02.944 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:03.997 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:04.082 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:06.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:08.242 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:09.272 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:09.987 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:13.253 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:14.305 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:15.357 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:15.368 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:19.542 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:19.816 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:20.019 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:21.155 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:24.087 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:24.621 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:25.307 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:26.746 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:29.557 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:29.701 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:30.017 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:32.990 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:35.025 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:35.631 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:36.190 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:39.388 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:39.458 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:41.212 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:42.126 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:45.094 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:46.062 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:46.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:47.117 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:49.752 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:51.199 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:51.488 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:51.831 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:55.417 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:56.850 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:57.271 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:36:57.664 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:01.046 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:01.168 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:02.411 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:02.895 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:06.333 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:07.230 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:07.743 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:08.965 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:11.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:12.993 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:13.581 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:13.733 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:17.216 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:19.060 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:19.106 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:19.219 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:21.917 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:23.581 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:24.025 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:24.080 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:28.252 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:29.182 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:30.093 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:30.413 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:33.940 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:34.106 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:35.512 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:36.004 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:38.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:38.591 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:40.951 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:41.894 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:43.732 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:43.859 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:45.915 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:46.587 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:48.533 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:49.574 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:51.255 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:51.469 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:54.257 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:54.786 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:57.233 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:37:57.691 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:00.141 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:00.485 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:02.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:03.221 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:05.339 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:07.076 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:08.257 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:08.346 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:10.162 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:12.306 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:13.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:14.323 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:14.734 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:18.080 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:19.237 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:19.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:19.951 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:23.783 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:24.828 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:25.593 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:25.655 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:29.493 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:30.414 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:31.238 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:31.522 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:36.028 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:36.812 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:37.182 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:37.343 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:41.540 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:41.680 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:41.938 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:42.130 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:46.708 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:47.044 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:47.308 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:47.330 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:52.114 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:52.853 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:53.259 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:53.442 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:58.452 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:58.582 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:58.599 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:38:59.228 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:04.272 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:04.529 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:04.741 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:04.826 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:09.133 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:09.765 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:10.151 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:10.419 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:13.440 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:15.804 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:15.947 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:17.230 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:19.059 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:21.335 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:21.818 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:22.452 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:23.769 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:25.511 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:26.363 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:27.210 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:28.726 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:30.406 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:32.156 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:32.462 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:33.954 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:35.928 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:36.631 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:38.995 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:39.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:41.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:42.219 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:44.449 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:45.006 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:46.453 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:46.484 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:49.636 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:51.048 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:51.355 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:51.981 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:55.628 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:56.247 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:56.488 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:39:57.940 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:01.878 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:02.637 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:03.108 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:03.222 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:07.399 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:08.403 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:08.404 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:08.788 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:12.932 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:14.053 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:14.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:14.417 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:18.414 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:19.155 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:19.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:20.214 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:23.896 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:24.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:25.804 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:25.877 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:28.903 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:29.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:31.373 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:31.376 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:33.866 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:36.364 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:36.548 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:37.095 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:38.386 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:40.922 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:40.939 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:42.793 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:44.627 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:46.550 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:46.949 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:48.372 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:49.958 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:51.802 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:52.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:53.139 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:54.701 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:56.577 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:57.514 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:57.744 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:40:59.606 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:01.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:02.035 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:02.349 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:05.230 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:07.355 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:08.056 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:08.069 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:11.476 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:12.044 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:12.703 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:14.183 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:16.035 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:17.593 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:18.734 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:19.750 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:22.083 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:23.604 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:23.987 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:24.390 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:27.552 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:28.370 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:28.991 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:30.406 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:32.858 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:33.469 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:33.991 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:34.935 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:38.237 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:38.707 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:38.935 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:39.360 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:42.844 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:43.726 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:44.071 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:44.080 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:47.446 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:49.564 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:49.581 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:49.675 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:51.928 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:54.914 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:55.225 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:55.636 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:41:58.134 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:00.574 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:00.577 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:01.187 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:03.302 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:05.002 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:06.137 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:06.971 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:08.667 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:10.688 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:11.654 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:12.710 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:14.297 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:16.355 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:16.562 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:17.465 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:19.442 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:20.847 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:22.220 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:22.624 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:25.178 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:26.490 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:26.553 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:27.008 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:30.321 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:32.190 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:32.209 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:32.418 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:35.300 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:36.613 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-08 23:42:37.796 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully

# %%
logger.info(
    f"Run duration: {t1 - t0:,.2f}s, on avg. {(t1-t0)/len(input_list):,.2f}s per batch"
)
# Out:
# 2024-11-08 23:42:37.853 | INFO     | __main__:<module>:1 - Run duration: 638.64s, on avg. 1.38s per batch

# %%
logger.info(f"Checking output...")
output_json = load_extracted(output_file)
# Out:
# 2024-11-08 23:42:37.869 | INFO     | __main__:<module>:1 - Checking output...

# %%
extracted_df = pd.DataFrame(output_json)
with pd.option_context("display.max_colwidth", None):
    display(extracted_df)
# Out:
#      parent_asin  \
# 0     B00BN5T30E
# 1     B07KXS41QL
# 2     B00XY0IVK4
# 3     B078GLDBZX
# 4     B01GY35HKE
# ...          ...
# 4621  B000P46NKC
# 4622  B076GYVWRY
# 4623  B004Y2VAVS
# 4624  B000B8J7K0
# 4625  B00XUYWTUC
#
#                                                                                                                                    item_title  \
# 0                                                                                                         Assassin's Creed IV Black Flag - PC
# 1     Nyko Charge Block Duo - 2 Port Controller Charging Station with Patented Charging Dongles and Micro-USB/AC Power Cord for PlayStation 4
# 2                                                                                                                      NHL 16 - PlayStation 4
# 3                                                               Street Fighter 30th Anniversary Collection - Nintendo Switch Standard Edition
# 4                                                                                                     Mass Effect Andromeda Deluxe - Xbox One
# ...                                                                                                                                       ...
# 4621                                                                                                                          Resident Evil 4
# 4622                                                            ivoler Carrying Storage Case for Nintendo Switch/For Switch OLED Model (2021)
# 4623                                                                          EastVita New Charger Dock + 4 x Battery for Nintendo Wii Remote
# 4624                                                                                                          Mario & Luigi: Partners In Time
# 4625                                                                                                   DC Superman Fun Pack - LEGO Dimensions
#
#                                                                                          tags
# 0                     [Open World, Action-Adventure, Historical, Pirate Theme, Single Player]
# 1     [Charging Station, Dual Charging, Convenient Accessory, PlayStation Compatible, Gadget]
# 2              [Sports, Hockey Simulation, Multiplayer, Annual Franchise, Realistic Gameplay]
# 3                         [Fighting, Classic Games, Multiplayer, Nostalgic, Game Compilation]
# 4                                   [RPG, Sci-Fi, Action, Exploration, Character Development]
# ...                                                                                       ...
# 4621                    [Survival Horror, Action-Adventure, Classic, Remake, Zombie Survival]
# 4622                   [Storage Case, Travel Accessory, Protection, Organizational, Portable]
# 4623            [Charging Dock, Battery Pack, Wii Accessory, Controller Charger, Convenience]
# 4624     [Role-Playing Game, Nintendo DS, Cooperative Gameplay, Mario Franchise, Original IP]
# 4625             [Interactive Gaming Figures, LEGO, Expansion Pack, DC Universe, Collectible]
#
# [4626 rows x 3 columns]

# %% [markdown]
# # Persist

# %%
output_fp = "../data/item_tags_from_llm.parquet"
extracted_df.to_parquet(output_fp, index=False)
