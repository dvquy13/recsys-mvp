# %% [markdown]
# # LLM Playground: Tagging items

# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio
import concurrent.futures
import os
import sys
import time
from typing import List

import pandas as pd
from datasets import load_dataset
from dotenv import load_dotenv
from loguru import logger
from openai import OpenAI
from pydantic import BaseModel

load_dotenv()

sys.path.insert(0, "..")

from llm.tagger import PROMPT as ITEM_TAGGING_PROMPT
from llm.tagger import SYSTEM_PROMPT
from llm.utils import load_extracted

# %% [markdown]
# # Controller

# %%
class Args(BaseModel):
    testing: bool = False
    run_name: str = "040-llm-tag-items"
    notebook_persist_dp: str = None
    random_seed: int = 41

    user_col: str = "user_id"
    item_col: str = "parent_asin"
    rating_col: str = "rating"
    timestamp_col: str = "timestamp"

    selected_cols: List[str] = ["title", "categories"]

    skip_processed: bool = False
    # processed_fp: str = "/Users/dvq/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/run__040-llm-tag-items__batch__1731068753.jsonl"
    processed_fp: str = None

    def init(self):
        self.notebook_persist_dp = os.path.abspath(f"data/{self.run_name}")
        os.makedirs(self.notebook_persist_dp, exist_ok=True)

        return self


args = Args().init()

print(args.model_dump_json(indent=2))
# Out:
# {
#   "testing": false,
#   "run_name": "040-llm-tag-items",
#   "notebook_persist_dp": "/home/dvquys/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items",
#   "random_seed": 41,
#   "user_col": "user_id",
#   "item_col": "parent_asin",
#   "rating_col": "rating",
#   "timestamp_col": "timestamp",
#   "selected_cols": [
#     "title",
#     "categories"
#   ],
#   "skip_processed": false,
#   "processed_fp": null
# }

# %% [markdown]
# # Load data

# %%
metadata_raw = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Video_Games", trust_remote_code=True
)
metadata_df = metadata_raw["full"].to_pandas()
metadata_df
# Out:
#                     main_category  \
# 0                     Video Games
# 1                     Video Games
# 2                     Video Games
# 3                     Video Games
# 4                     Video Games
# ...                           ...
# 137264                       None
# 137265                Video Games
# 137266  Cell Phones & Accessories
# 137267                       None
# 137268                       None
#
#                                                     title  average_rating  \
# 0                          Dash 8-300 Professional Add-On             5.0
# 1                       Phantasmagoria: A Puzzle of Flesh             4.1
# 2        NBA 2K17 - Early Tip Off Edition - PlayStation 4             4.3
# 3       Nintendo Selects: The Legend of Zelda Ocarina ...             4.9
# 4        Thrustmaster Elite Fitness Pack for Nintendo Wii             3.0
# ...                                                   ...             ...
# 137264  Story of Seasons: Pioneers Of Olive Town (Nint...             4.5
# 137265           MotoGP 18 (PC DVD) UK IMPORT REGION FREE             4.0
# 137266  Century Accessory Soft Silicone Protective Ski...             2.9
# 137267  Hasbro Interactive Mr. Potato Head Activity Pa...             3.9
# 137268                                  Worms: Armageddon             4.3
#
#         rating_number                                           features  \
# 0                   1  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                  18                                       [Windows 95]
# 2                 223  [The #1 rated NBA video game simulation series...
# 3                  22  [Authentic Nintendo Selects: The Legend of Zel...
# 4                   3  [Includes (9) Total Accessories, Pedometer, Wi...
# ...               ...                                                ...
# 137264            397  [A wild world of discovery - tame the wilderne...
# 137265              1  [Brand new game engine - MotoGP18 has been reb...
# 137266             19  [Easy access to all buttons, controls and port...
# 137267              5                                                 []
# 137268             13                                                 []
#
#                                               description  price  \
# 0       [The Dash 8-300 Professional Add-On lets you p...   None
# 1                                                      []   None
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 3                                                      []  37.42
# 4       [The Thrustmaster Motion Plus Elite Fitness Pa...   None
# ...                                                   ...    ...
# 137264  [Product Description, Inspired by Tales of you...  31.04
# 137265  [Become the champion of the 2018 MotoGP Season...   None
# 137266  [This soft case cover will add a splash of col...   None
# 137267  [Amazon.com, Everyone's favorite master-of-dis...   None
# 137268  [Product Description, Do you ever wonder what ...   None
#
#                                                    images  \
# 0       {'hi_res': [None], 'large': ['https://m.media-...
# 1       {'hi_res': ['https://m.media-amazon.com/images...
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 3       {'hi_res': ['https://m.media-amazon.com/images...
# 4       {'hi_res': [None, None, None, None, None, None...
# ...                                                   ...
# 137264  {'hi_res': ['https://m.media-amazon.com/images...
# 137265  {'hi_res': ['https://m.media-amazon.com/images...
# 137266  {'hi_res': ['https://m.media-amazon.com/images...
# 137267  {'hi_res': [None, 'https://m.media-amazon.com/...
# 137268  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos              store  \
# 0                 {'title': [], 'url': [], 'user_id': []}           Aerosoft
# 1                 {'title': [], 'url': [], 'user_id': []}             Sierra
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...                 2K
# 3                 {'title': [], 'url': [], 'user_id': []}     Amazon Renewed
# 4                 {'title': [], 'url': [], 'user_id': []}       THRUSTMASTER
# ...                                                   ...                ...
# 137264            {'title': [], 'url': [], 'user_id': []}   Marvelous Europe
# 137265            {'title': [], 'url': [], 'user_id': []}          Milestone
# 137266            {'title': [], 'url': [], 'user_id': []}  Century Accessory
# 137267            {'title': [], 'url': [], 'user_id': []}             Hasbro
# 137268            {'title': [], 'url': [], 'user_id': []}             Hasbro
#
#                                                categories  \
# 0                                [Video Games, PC, Games]
# 1                                [Video Games, PC, Games]
# 2                     [Video Games, PlayStation 4, Games]
# 3       [Video Games, Legacy Systems, Nintendo Systems...
# 4       [Video Games, Legacy Systems, Nintendo Systems...
# ...                                                   ...
# 137264              [Video Games, Nintendo Switch, Games]
# 137265             [Video Games, Game Genre of the Month]
# 137266  [Video Games, Legacy Systems, Xbox Systems, Xb...
# 137267                           [Video Games, PC, Games]
# 137268  [Video Games, Legacy Systems, Sega Systems, Se...
#
#                                                   details parent_asin  \
# 0       {"Pricing": "The strikethrough price is the Li...  B000FH0MHO
# 1       {"Best Sellers Rank": {"Video Games": 137612, ...  B00069EVOG
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 3       {"Best Sellers Rank": {"Video Games": 51019, "...  B07SZJZV88
# 4       {"Release date": "November 1, 2009", "Pricing"...  B002WH4ZJG
# ...                                                   ...         ...
# 137264  {"Release date": "March 26, 2021", "Best Selle...  B09XQJS4CZ
# 137265  {"Pricing": "The strikethrough price is the Li...  B07DGPTGNV
# 137266  {"Package Dimensions": "2.76 x 2.76 x 0.2 inch...  B00HUWCQBW
# 137267  {"Release date": "July 24, 1999", "Best Seller...  B00002S9MH
# 137268  {"Release date": "December 3, 1999", "Best Sel...  B00001OX4N
#
#        bought_together subtitle author
# 0                 None     None   None
# 1                 None     None   None
# 2                 None     None   None
# 3                 None     None   None
# 4                 None     None   None
# ...                ...      ...    ...
# 137264            None     None   None
# 137265            None     None   None
# 137266            None     None   None
# 137267            None     None   None
# 137268            None     None   None
#
# [137269 rows x 16 columns]

# %%
metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")
# Out:
# [{'parent_asin': 'B09ZYFYT5J',
#   'title': 'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch',
#   'categories': array(['Video Games', 'PC', 'Accessories', 'Gaming Keyboards'],
#         dtype=object)},
#  {'parent_asin': 'B00GZ6TX7E',
#   'title': 'NEW HOLLAND SKYLINE [Xbox 360]',
#   'categories': array(['Video Games', 'Legacy Systems', 'Xbox Systems', 'Xbox 360',
#          'Interactive Gaming Figures'], dtype=object)},
#  {'parent_asin': 'B09QZ2RZLV',
#   'title': 'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch',
#   'categories': array(['Video Games', 'Nintendo Switch', 'Accessories'], dtype=object)},
#  {'parent_asin': 'B000021Y1B',
#   'title': 'Rampage 2: Universal Tour',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Nintendo 64',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B07MMP45FS',
#   'title': 'Warner Home Video Lego Jurassic World PS4',
#   'categories': array(['Video Games', 'PlayStation 4', 'Games'], dtype=object)},
#  {'parent_asin': 'B00EEH3U2K',
#   'title': 'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B001A33GMU',
#   'title': 'Mysteryville - PC (Jewel case)',
#   'categories': array(['Video Games', 'PC', 'Games'], dtype=object)},
#  {'parent_asin': 'B0BV24K2CD',
#   'title': 'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case',
#   'categories': array(['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Wii',
#          'Games'], dtype=object)},
#  {'parent_asin': 'B00UBRKJFI',
#   'title': 'Wolfenstein The Old Blood\u3000[ceroZ]',
#   'categories': array([], dtype=object)},
#  {'parent_asin': 'B003C3V6WI',
#   'title': 'Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]',
#   'categories': array([], dtype=object)}]

# %% [markdown]
# # Call OpenAI to get tags

# %%
sampled_items = metadata_df.sample(10, random_state=args.random_seed)[
    [args.item_col, *args.selected_cols]
].to_dict(orient="records")

# %%
prompt = ITEM_TAGGING_PROMPT.format(input_list=sampled_items)
prompt
# Out:
# '\nFor each of the following items, generate a set of tags that capture the main features, target audience, platform compatibility, and item type (e.g., accessory, game, hardware).\n\nReturn the output as a list of JSON objects, where each object includes the original item `title`, `parent_asin`, and a list of tags.\n\nFocus on adding tags that help shoppers easily find these items based on genre, brand associations, and product functionality.\n\nIf possible, add new information that is not obvious from the item title.\n\nDo not include the tags that are similar to those in the input categories, for example do not include tags about gaming platforms as output.\n\n<EXAMPLE>\n\nExample item titles with JSON input and output:\n\nInput:  \n[\n    { "parent_asin": "B09ZYFYT5J", "title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch" },\n    { "parent_asin": "B00GZ6TX7E", "title": "NEW HOLLAND SKYLINE [Xbox 360]" },\n    { "parent_asin": "B09QZ2RZLV", "title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch" }\n]\n\nOutput:  \n[\n    {\n        "parent_asin": "B09ZYFYT5J",\n        "item_title": "Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch",\n        "tags": ["Keyboard Accessory", "Cherry MX", "Mechanical Keyboard", "Switch Film", "Gateron", "Repair"]\n    },\n    {\n        "parent_asin": "B00GZ6TX7E",\n        "item_title": "NEW HOLLAND SKYLINE [Xbox 360]",\n        "tags": ["Racing", "NEW HOLLAND", "Skyline", "Retro"]\n    },\n    {\n        "parent_asin": "B09QZ2RZLV",\n        "item_title": "HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch",\n        "tags": ["Headset", "Nintendo Switch", "Switch Lite", "Pikachu", "Pokemon", "Gaming Accessory"]\n    }\n]\n\n</EXAMPLE>\n\nInput:\n[{\'parent_asin\': \'B09ZYFYT5J\', \'title\': \'Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch\', \'categories\': array([\'Video Games\', \'PC\', \'Accessories\', \'Gaming Keyboards\'],\n      dtype=object)}, {\'parent_asin\': \'B00GZ6TX7E\', \'title\': \'NEW HOLLAND SKYLINE [Xbox 360]\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Xbox Systems\', \'Xbox 360\',\n       \'Interactive Gaming Figures\'], dtype=object)}, {\'parent_asin\': \'B09QZ2RZLV\', \'title\': \'HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch\', \'categories\': array([\'Video Games\', \'Nintendo Switch\', \'Accessories\'], dtype=object)}, {\'parent_asin\': \'B000021Y1B\', \'title\': \'Rampage 2: Universal Tour\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Nintendo 64\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B07MMP45FS\', \'title\': \'Warner Home Video Lego Jurassic World PS4\', \'categories\': array([\'Video Games\', \'PlayStation 4\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B00EEH3U2K\', \'title\': \'Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B001A33GMU\', \'title\': \'Mysteryville - PC (Jewel case)\', \'categories\': array([\'Video Games\', \'PC\', \'Games\'], dtype=object)}, {\'parent_asin\': \'B0BV24K2CD\', \'title\': \'Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case\', \'categories\': array([\'Video Games\', \'Legacy Systems\', \'Nintendo Systems\', \'Wii\',\n       \'Games\'], dtype=object)}, {\'parent_asin\': \'B00UBRKJFI ...

# %%
client = OpenAI()


# Define the structured output format using Pydantic for a single item
class ItemTag(BaseModel):
    parent_asin: str
    item_title: str
    tags: List[str]


# Define the output format to wrap the list of items within an object
class ItemTaggingOutput(BaseModel):
    items: List[ItemTag]  # Wrap list in an "items" field

# %%
def retrieve_item_tags_from_llm(item_metadata: List[dict]):
    prompt = ITEM_TAGGING_PROMPT.format(input_list=item_metadata)

    completion = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": SYSTEM_PROMPT,
            },
            {"role": "user", "content": prompt},
        ],
        response_format=ItemTaggingOutput,
    )

    tagged_items = completion.choices[0].message.parsed

    return tagged_items.dict()["items"]

# %%
extracted_tags = retrieve_item_tags_from_llm(sampled_items)
with pd.option_context("display.max_colwidth", None):
    display(pd.DataFrame(extracted_tags))
# Out:
#   parent_asin  \
# 0  B09ZYFYT5J
# 1  B00GZ6TX7E
# 2  B09QZ2RZLV
# 3  B000021Y1B
# 4  B07MMP45FS
# 5  B00EEH3U2K
# 6  B001A33GMU
# 7  B0BV24K2CD
# 8  B00UBRKJFI
# 9  B003C3V6WI
#
#                                                                                                                                                      item_title  \
# 0                              Gliging 120Pcs/Set MX Switch Films Mechanical Keyboard Switches stabilizer Switch Film Repair for Cherry MX kailh Gateron Switch
# 1                                                                                                                                NEW HOLLAND SKYLINE [Xbox 360]
# 2       HORI Gaming Headset (Pikachu POP) for Nintendo Switch & Switch Lite - Officially Licensed by Nintendo & Pokemon Company International - Nintendo Switch
# 3                                                                                                                                     Rampage 2: Universal Tour
# 4                                                                                                                     Warner Home Video Lego Jurassic World PS4
# 5                                                                                                  Skulls of the Shogun: Bone-a-Fide Edition [Online Game Code]
# 6                                                                                                                                Mysteryville - PC (Jewel case)
# 7  Wireless Controller Replacement for WII Controller,GLOWANT 2 Pack Wii Remote Controller Compatible with Wii/Wii U Console with Wrist Strap and Silicone Case
# 8                                                                                                                             Wolfenstein The Old Blood [ceroZ]
# 9                                                                                       Hard Drive Data Migration Transfer Cable Kit For XBOX 360 [Electronics]
#
#                                                                                               tags
# 0          [Keyboard Accessory, Cherry MX, Mechanical Keyboard, Switch Film, Gateron, DIY Modding]
# 1                             [Racing Game, Simulation, NEW HOLLAND, Farm Equipment, Retro Gaming]
# 2              [Gaming Headset, Anime Merchandise, Pikachu, Gaming Accessory, Officially Licensed]
# 3                                [Action Game, Legacy Title, Multiplayer, Retro Gaming, Nostalgia]
# 4                   [Action-Adventure, Family-Friendly, Lego Series, Movie Tie-In, Co-op Gameplay]
# 5                  [Strategy Game, Online Multiplayer, Indie Game, Turn-Based, Historical Fiction]
# 6                            [Puzzle Game, Adventure, Single Player, Casual Gaming, Mystery Genre]
# 7  [Controller Accessory, Wii Compatible, Replacement Controller, Gaming Accessory, Silicone Grip]
# 8             [First-Person Shooter, Action-Adventure, Single Player, Story-Driven, Adult Content]
# 9                 [Data Transfer Tool, Xbox Accessory, Hardware Tool, System Upgrade, Electronics]

# %% [markdown]
# # Get sample items

# %%
train_df = pd.read_parquet("../data/train_features_neg_df.parquet")

# %%
all_items = train_df[args.item_col].unique()
logger.info(f"{len(all_items)=}")
# Out:
# 2024-11-10 18:47:18.821 | INFO     | __main__:<module>:2 - len(all_items)=4630

# %%
all_items_df = metadata_df.loc[lambda df: df[args.item_col].isin(all_items)]

# %%
all_items_df
# Out:
#           main_category                                              title  \
# 2           Video Games   NBA 2K17 - Early Tip Off Edition - PlayStation 4
# 15          Video Games  Warhammer 40,000 Dawn of War Game of the Year ...
# 46          Video Games  Polk Audio Striker Zx Xbox One Gaming Headset ...
# 63          Video Games  The Legend of Heroes: Trails in the Sky - Sony...
# 65          Video Games            Harry Potter: Goblet of Fire - Sony PSP
# ...                 ...                                                ...
# 118437      Video Games                                    Resident Evil 4
# 118457  All Electronics  ivoler Carrying Storage Case for Nintendo Swit...
# 118459      Video Games  EastVita New Charger Dock + 4 x Battery for Ni...
# 118510      Video Games                    Mario & Luigi: Partners In Time
# 118595     Toys & Games             DC Superman Fun Pack - LEGO Dimensions
#
#         average_rating  rating_number  \
# 2                  4.3            223
# 15                 4.0             68
# 46                 3.9            169
# 63                 4.4             91
# 65                 3.6             38
# ...                ...            ...
# 118437             4.6           1133
# 118457             4.8          13702
# 118459             3.9            676
# 118510             4.6            607
# 118595             4.7            436
#
#                                                  features  \
# 2       [The #1 rated NBA video game simulation series...
# 15      [Real-time strategy game based on the popular ...
# 46      [Powered by 40 years of audio heritage and tun...
# 63      [After a brief hiatus since its last release i...
# 65      [All the Magic of the Movie - Characters model...
# ...                                                   ...
# 118437                                                 []
# 118457  [Deluxe Travel Carrying Case. Specially design...
# 118459  [Include: 1x Remote Controller Charger 4 x 280...
# 118510  [Players use the top screen to study the land,...
# 118595  [Brand New in box. The product ships with all ...
#
#                                               description  price  \
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 15      [From the Manufacturer, This Game of The Year ...  29.95
# 46      [Our ProFit Comfort system creates a lightweig...   None
# 63      [Product Description, In the peaceful town of ...  185.0
# 65      [From the Manufacturer, Be Harry Potter in a n...  19.43
# ...                                                   ...    ...
# 118437  [In Resident Evil 4 you'll know a new type of ...  44.98
# 118457                                                 []  26.39
# 118459        [Charger Dock + 4 x Battery for Wii Remote]   None
# 118510  [Mario and Luigi: Partners In Time an insane s...  99.99
# 118595  [When a mysterious and powerful vortex suddenl...   None
#
#                                                    images  \
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 15      {'hi_res': [None, 'https://m.media-amazon.com/...
# 46      {'hi_res': ['https://m.media-amazon.com/images...
# 63      {'hi_res': ['https://m.media-amazon.com/images...
# 65      {'hi_res': [None, 'https://m.media-amazon.com/...
# ...                                                   ...
# 118437  {'hi_res': ['https://m.media-amazon.com/images...
# 118457  {'hi_res': ['https://m.media-amazon.com/images...
# 118459  {'hi_res': ['https://m.media-amazon.com/images...
# 118510  {'hi_res': ['https://m.media-amazon.com/images...
# 118595  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos            store  \
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...               2K
# 15                {'title': [], 'url': [], 'user_id': []}              THQ
# 46                {'title': [], 'url': [], 'user_id': []}       Polk Audio
# 63      {'title': ['The Legend of Heroes: Trails in th...      Xseed Games
# 65                {'title': [], 'url': [], 'user_id': []}  Electronic Arts
# ...                                                   ...              ...
# 118437            {'title': [], 'url': [], 'user_id': []}           Capcom
# 118457            {'title': [], 'url': [], 'user_id': []}           ivoler
# 118459            {'title': [], 'url': [], 'user_id': []}         EastVita
# 118510            {'title': [], 'url': [], 'user_id': []}         Nintendo
# 118595            {'title': [], 'url': [], 'user_id': []}      WARNER BROS
#
#                                                categories  \
# 2                     [Video Games, PlayStation 4, Games]
# 15                               [Video Games, PC, Games]
# 46         [Video Games, Xbox One, Accessories, Headsets]
# 63      [Video Games, Legacy Systems, PlayStation Syst...
# 65      [Purchase Circles, Geography, United States, M...
# ...                                                   ...
# 118437  [Video Games, Legacy Systems, Nintendo Systems...
# 118457  [Video Games, Legacy Systems, Nintendo Systems...
# 118459  [Video Games, Legacy Systems, Nintendo Systems...
# 118510  [Video Games, Legacy Systems, Nintendo Systems...
# 118595  [Video Games, Legacy Systems, PlayStation Syst...
#
#                                                   details parent_asin  \
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 15      {"Release date": "September 20, 2005", "Best S...  B001EYUX4Y
# 46      {"Release date": "October 5, 2014", "Best Sell...  B00OLOQGAY
# 63      {"Release date": "March 29, 2011", "Best Selle...  B004BV5O0U
# 65      {"Release date": "September 8, 2006", "Best Se...  B001ELJEA6
# ...                                                   ...         ...
# 118437  {"Release date": "June 19, 2007", "Best Seller...  B000P46NKC
# 118457  {"Product Dimensions": "11.2 x 4 x 9 inches", ...  B076GYVWRY
# 118459  {"Pricing": "The strikethrough price is the Li...  B004Y2VAVS
# 118510  {"Release date": "November 28, 2005", "Best Se...  B000B8J7K0
# 118595  {"Product Dimensions": "7.99 x 6.77 x 7.4 inch...  B00XUYWTUC
#
#        bought_together subtitle author
# 2                 None     None   None
# 15                None     None   None
# 46                None     None   None
# 63                None     None   None
# 65                None     None   None
# ...                ...      ...    ...
# 118437            None     None   None
# 118457            None     None   None
# 118459            None     None   None
# 118510            None     None   None
# 118595            None     None   None
#
# [4630 rows x 16 columns]

# %% [markdown]
# # Batch extraction

# %%
processed_fp = args.processed_fp
skip_processed = args.skip_processed

# %% [markdown]
# ## Processed outputs

# %%
if not skip_processed and processed_fp is not None and os.path.exists(processed_fp):
    logger.info(f"Loading processed data from {processed_fp}...")
    processed_json = load_extracted(processed_fp)
    processed_df = pd.DataFrame(processed_json)
    to_process_df = all_items_df.loc[
        lambda df: ~df[args.item_col].isin(processed_df[args.item_col])
    ]
    logger.info(
        f"{all_items_df.shape=} - {processed_df.shape=} = {to_process_df.shape=}"
    )
    output_file = processed_fp
else:
    to_process_df = all_items_df.copy()
    output_file = f"{args.notebook_persist_dp}/{args.run_name}.jsonl"

# %% [markdown]
# ## Run

# %%
run_datetime = int(time.time())
run_name = f"run__{args.run_name}__batch__{run_datetime}"
log_file = f"{args.notebook_persist_dp}/{args.run_name}.log"
pipeline_metadata = dict()

logger.add(
    output_file,
    filter=lambda record: "[OUTPUT]" in record["message"],
    level="DEBUG",
    serialize=True,
    mode="a",
)
logger.add(
    log_file,
    filter=lambda record: "[COLLECT]" in record["message"],
    level="ERROR",
    serialize=True,
)
# Out:
# 2

# %%
# Group search queries as batch to send to Gemini API
num_inputs_per_batch = 10
iterator_group_df = (
    to_process_df.reset_index(drop=True)
    .reset_index()
    .assign(group=lambda df: df["index"] // num_inputs_per_batch)
    .groupby(["group"])[[args.item_col, *args.selected_cols]]
    .apply(lambda df: df.to_dict(orient="records"))
    .to_frame("item_metadata")
)
iterator_group_df
# Out:
#                                            item_metadata
# group
# 0      [{'parent_asin': 'B00Z9TLVK0', 'title': 'NBA 2...
# 1      [{'parent_asin': 'B00BN5T30E', 'title': 'Assas...
# 2      [{'parent_asin': 'B00YM7AKLG', 'title': 'FIFA ...
# 3      [{'parent_asin': 'B003QCJLRM', 'title': 'Zumba...
# 4      [{'parent_asin': 'B07BHXMYV6', 'title': 'Valky...
# ...                                                  ...
# 458    [{'parent_asin': 'B001EYUQC8', 'title': '007 Q...
# 459    [{'parent_asin': 'B000Q6J51S', 'title': 'Phoen...
# 460    [{'parent_asin': 'B078S9S2XF', 'title': 'Shant...
# 461    [{'parent_asin': 'B07HPF7PRT', 'title': 'POUND...
# 462    [{'parent_asin': 'B01N6QKT7H', 'title': 'Ninte...
#
# [463 rows x 1 columns]

# %%
input_list = iterator_group_df["item_metadata"].values.tolist()

# %%
if args.testing:
    logger.info(f"testing=True so only process 10 prompts")
    input_list = input_list[:10]
logger.info(f"Number of prompts to be batch-run: {len(input_list)}")
pipeline_metadata["num_prompts_processed"] = len(input_list)
# Out:
# 2024-11-10 18:47:19.009 | INFO     | __main__:<module>:4 - Number of prompts to be batch-run: 463

# %%
max_workers = 4


def retrieve_item_tags_from_llm_wrapper(fn):
    def __wrapper(*args, **kwargs):
        llm_results = fn(*args, **kwargs)
        input_item_metadata = args[0]
        (
            logger.opt(lazy=True)
            .bind(input_item_metadata=input_item_metadata, llm_extracted=llm_results)
            .debug("[OUTPUT] LLM Extracted successfully")
        )
        return llm_results

    return __wrapper


async def retrieve_item_tags_from_llm_async():
    loop = asyncio.get_event_loop()

    # Use a ThreadPoolExecutor to run the functions in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Use list comprehension to submit tasks to the executor
        futures = [
            loop.run_in_executor(
                executor,
                retrieve_item_tags_from_llm_wrapper(retrieve_item_tags_from_llm),
                input_item_metadata,
            )
            for input_item_metadata in input_list
        ]

        # Wait for all tasks to complete
        results = await asyncio.gather(*futures)

    return results

# %%
t0 = time.perf_counter()
logger.debug(f"Outputing to {output_file}...")
try:
    logger.info(
        f"""To monitor the progress, run in a separate CLI: \n```\nwatch -n 0.1 "grep -wF 'LLM Extracted successfully' {output_file} | wc -l"\n```"""
    )
    results = await retrieve_item_tags_from_llm_async()
finally:
    t1 = time.perf_counter()
# Out:
# 2024-11-10 18:47:19.028 | DEBUG    | __main__:<module>:2 - Outputing to /home/dvquys/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl...
# 2024-11-10 18:47:19.028 | INFO     | __main__:<module>:4 - To monitor the progress, run in a separate CLI:
# ```
# watch -n 0.1 "grep -wF 'LLM Extracted successfully' /home/dvquys/frostmourne/recsys-mvp/notebooks/data/040-llm-tag-items/040-llm-tag-items.jsonl | wc -l"
# ```
# 2024-11-10 18:47:24.975 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:25.065 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:25.139 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:25.308 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:29.803 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:30.145 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:30.560 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:31.669 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:34.911 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:35.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:36.014 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:37.561 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:41.305 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:41.493 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:41.902 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:43.205 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:46.557 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:47.555 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:47.992 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:48.843 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:52.077 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:52.689 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:53.148 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:53.895 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:57.642 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:57.748 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:58.924 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:47:59.039 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:03.467 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:03.567 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:04.669 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:04.688 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:08.320 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:09.410 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:10.195 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:11.741 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:13.687 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:15.075 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:15.320 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:16.949 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:19.362 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:20.554 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:20.909 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:22.664 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:25.628 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:26.485 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:26.659 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:27.257 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:31.235 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:31.561 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:32.403 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:32.868 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:36.162 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:36.695 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:37.866 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:38.332 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:41.747 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:43.064 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:43.294 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:43.661 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:46.325 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:47.892 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:48.981 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:49.421 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:51.857 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:53.520 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:55.218 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:55.485 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:57.706 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:59.117 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:48:59.538 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:00.949 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:03.018 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:04.440 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:04.976 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:05.261 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:08.370 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:09.548 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:10.648 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:10.998 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:13.839 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:15.826 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:15.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:16.489 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:19.577 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:21.224 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:21.331 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:21.620 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:24.508 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:26.157 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:27.035 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:27.339 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:29.984 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:32.078 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:32.268 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:33.339 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:35.961 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:37.459 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:37.587 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:40.107 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:41.124 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:42.757 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:42.871 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:44.462 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:46.777 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:48.387 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:48.651 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:49.042 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:52.185 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:53.190 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:54.284 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:54.729 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:57.861 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:58.459 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:49:59.933 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:02.093 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:02.741 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:02.979 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:07.150 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:07.167 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:08.143 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:08.526 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:12.245 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:12.687 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:13.207 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:13.288 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:17.746 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:18.323 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:18.659 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:19.189 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:23.199 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:23.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:24.257 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:24.416 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:28.490 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:29.017 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:29.276 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:29.874 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:34.182 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:34.370 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:35.294 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:36.938 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:39.807 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:40.699 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:40.914 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:41.564 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:44.836 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:46.133 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:46.147 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:46.692 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:50.048 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:52.078 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:52.096 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:52.399 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:55.210 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:55.848 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:56.548 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:50:58.632 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:00.931 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:02.117 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:03.097 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:05.119 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:06.486 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:06.942 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:09.134 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:09.992 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:11.687 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:12.195 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:13.564 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:15.198 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:17.225 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:17.961 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:18.208 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:20.997 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:22.710 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:23.402 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:24.365 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:25.390 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:27.490 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:28.531 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:28.864 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:30.632 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:32.975 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:33.812 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:34.160 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:35.999 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:38.413 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:39.310 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:39.940 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:41.713 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:44.893 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:45.319 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:45.635 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:47.548 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:50.590 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:50.957 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:51.226 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:51.806 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:56.222 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:56.542 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:56.873 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:51:57.375 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:01.577 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:02.157 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:03.220 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:04.247 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:06.217 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:07.517 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:09.096 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:10.174 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:11.707 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:12.024 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:14.371 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:14.477 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:15.658 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:17.086 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:19.077 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:20.142 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:20.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:23.596 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:23.651 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:25.383 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:26.996 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:28.959 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:29.334 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:29.749 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:32.123 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:34.542 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:34.740 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:34.932 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:37.096 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:39.180 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:39.634 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:40.036 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:42.736 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:43.698 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:44.853 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:45.274 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:47.528 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:48.899 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:50.094 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:50.764 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:52.277 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:53.255 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:55.045 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:56.297 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:57.835 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:52:58.919 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:00.520 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:00.744 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:02.655 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:03.444 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:05.854 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:06.851 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:08.075 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:08.161 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:11.181 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:12.481 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:13.343 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:14.257 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:15.697 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:17.259 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:19.269 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:19.541 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:20.062 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:23.227 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:24.685 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:25.268 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:25.291 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:29.830 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:30.301 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:30.417 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:30.960 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:35.360 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:35.431 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:35.537 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:36.044 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:39.573 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:40.287 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:41.021 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:41.758 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:44.541 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:45.070 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:46.111 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:46.576 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:49.181 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:50.293 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:51.390 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:52.083 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:52.605 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:54.697 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:55.867 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:57.524 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:58.156 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:53:59.636 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:01.115 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:03.373 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:03.800 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:05.474 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:06.709 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:08.545 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:09.192 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:11.290 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:12.025 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:13.543 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:13.675 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:16.042 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:17.598 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:18.063 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:18.186 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:21.333 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:23.623 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:23.942 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:24.308 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:27.480 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:29.384 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:29.444 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:29.737 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:31.963 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:34.696 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:34.947 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:35.522 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:36.844 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:40.443 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:40.631 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:40.929 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:42.239 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:45.820 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:46.266 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:46.304 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:47.708 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:51.547 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:51.686 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:51.868 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:54.798 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:56.723 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:56.770 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:54:57.727 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:00.056 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:02.092 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:02.336 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:03.038 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:04.336 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:07.528 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:07.535 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:08.321 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:10.190 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:12.917 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:13.379 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:14.140 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:15.364 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:19.239 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:19.504 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:20.621 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:21.457 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:23.634 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:24.958 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:25.946 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:27.881 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:29.229 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:31.277 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:31.608 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:34.218 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:34.903 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:36.521 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:37.007 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:39.784 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:40.526 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:41.600 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:42.338 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:45.068 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:45.297 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:46.592 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:47.588 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:49.778 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:50.839 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:52.011 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:52.976 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:55.555 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:55.672 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:56.568 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:55:57.814 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:00.698 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:01.209 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:02.609 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:03.448 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:05.756 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:06.865 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:08.334 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:08.428 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:11.248 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:11.466 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:13.134 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:13.687 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:16.357 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:17.837 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:17.944 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:18.909 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:20.712 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:22.497 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:23.587 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:23.816 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:25.200 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:27.867 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:29.175 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:29.927 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:30.218 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:32.431 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:34.493 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:35.280 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:36.102 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:37.131 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:40.246 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:40.668 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:41.462 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:42.368 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:45.922 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:46.480 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:46.514 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:48.166 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:51.498 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:52.185 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:52.587 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:53.413 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:56.705 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:57.480 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:58.117 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:56:58.971 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:02.169 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:02.809 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:03.314 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:04.477 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:07.539 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:07.870 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:08.344 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:09.736 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:12.706 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:12.869 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:13.027 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:14.628 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:17.972 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:18.876 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:19.272 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:19.944 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:22.597 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:24.445 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:24.877 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:25.843 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:27.630 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:28.743 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:31.191 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:31.735 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:32.762 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:34.619 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:36.521 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:37.195 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:38.558 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:39.843 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:42.532 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:42.847 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:44.510 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:45.565 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully
# 2024-11-10 18:57:48.150 | DEBUG    | __main__:__wrapper:11 - [OUTPUT] LLM Extracted successfully

# %%
logger.info(
    f"Run duration: {t1 - t0:,.2f}s, on avg. {(t1-t0)/len(input_list):,.2f}s per batch"
)
# Out:
# 2024-11-10 18:57:48.185 | INFO     | __main__:<module>:1 - Run duration: 629.13s, on avg. 1.36s per batch

# %%
logger.info(f"Checking output...")
output_json = load_extracted(output_file)
# Out:
# 2024-11-10 18:57:48.202 | INFO     | __main__:<module>:1 - Checking output...

# %%
extracted_df = pd.DataFrame(output_json)
with pd.option_context("display.max_colwidth", None):
    display(extracted_df)
# Out:
#      parent_asin  \
# 0     B003QCJLRM
# 1     B08K39H8ST
# 2     B09JY72CNG
# 3     B009GE437W
# 4     B0086VPUHI
# ...          ...
# 4623  B000P46NKC
# 4624  B076GYVWRY
# 4625  B004Y2VAVS
# 4626  B000B8J7K0
# 4627  B00XUYWTUC
#
#                                                                                                                                                                                                    item_title  \
# 0                                                                                                                                                                                Zumba Fitness - Nintendo Wii
# 1                                                                                               Controller Gear Xbox One Controller Stand v2.0, Licensed Accessory Display Stand (Controller Sold Separately)
# 2                                 Razer Goliathus Extended Chroma Gaming Mouse Pad: Customizable Chroma RGB Lighting - Soft, Cloth Material - Balanced Control & Speed - Non-Slip Rubber Base - Mercury White
# 3                                                                                                                                                                           Remote Plus, Mario - Nintendo Wii
# 4                                                                                                                                               Grand Theft Auto V: Premium Edition - Xbox One [Digital Code]
# ...                                                                                                                                                                                                       ...
# 4623                                                                                                                                                                                          Resident Evil 4
# 4624  ivoler Carrying Storage Case for Nintendo Switch/For Switch OLED Model (2021),Portable Travel All Protective Hard Messenger Bag Soft Lining 18Games for Switch Console Pro Controller Accessories Black
# 4625                                                                                                                                          EastVita New Charger Dock + 4 x Battery for Nintendo Wii Remote
# 4626                                                                                                                                                                          Mario & Luigi: Partners In Time
# 4627                                                                                                                                                                   DC Superman Fun Pack - LEGO Dimensions
#
#                                                                                       tags
# 0                             [Fitness, Dance, Wii Exercise, Party Game, Active Lifestyle]
# 1                            [Controller Stand, Display, Xbox Accessory, Storage Solution]
# 2                    [Mouse Pad, RGB Lighting, High Precision, Gaming Accessory, Non-Slip]
# 3                       [Controller, Wii Remote, Mario, Licensed Product, Family-Friendly]
# 4                 [Open World, Action-Adventure, Digital Download, Mature Audience, Crime]
# ...                                                                                    ...
# 4623                    [Survival Horror, Classic Game, Action, Zombie Apocalypse, Legacy]
# 4624  [Carrying Case, Travel Accessory, Gaming Storage, Protective Cover, Nintendo Switch]
# 4625                        [Charging Dock, Wii Remote, Battery Pack, Accessory, Nintendo]
# 4626                                 [RPG, Cooperative Play, Nintendo DS, Comedy, Classic]
# 4627                        [Interactive Toy, LEGO, Multiverse, DC Comics, Action Figures]
#
# [4628 rows x 3 columns]

# %% [markdown]
# # Persist

# %%
output_fp = "../data/item_tags_from_llm.parquet"
extracted_df.to_parquet(output_fp, index=False)
